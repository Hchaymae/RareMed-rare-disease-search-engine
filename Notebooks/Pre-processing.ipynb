# %%
import pandas as pd
import numpy as np
import os
import re

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import WordNetLemmatizer


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('float_format', '{:f}'.format)

from sklearn.metrics.pairwise import cosine_similarity


import psycopg2

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/admin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/admin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/admin/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/admin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
txt_directory = "../Data"

# %% [markdown]
# <H1>Turn PDFs into rows of a DataFrame</H1>

# %%
def extract_text(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# %%
def process_texts_in_directory(directory_path):
    result = []
    for filename in os.listdir(directory_path):
        if filename.endswith('.txt'):  # Process only .txt files
            file_path = os.path.join(directory_path, filename)
            content = extract_text(file_path)
            if content is not None:
                # Append file name (without extension) and content to the data list
                result.append({"title": os.path.splitext(filename)[0], "content": content})
    
    # Convert the list to a DataFrame
    return pd.DataFrame(result)

# %%
data = process_texts_in_directory(txt_directory)
data.head()
# Out:
#                                                title  \
# 0  Predisposing factors for incomplete spontaneou...
# 1  Gastrointestinal LCH a rare manifestation of L...
# 2  A rare case report of omental synovial sarcoma...
# 3  Chronic brucellosis with sacroiliitis A case r...
# 4  Unilateral adrenal metastases as an unusual pr...
#
#                                              content
# 0  ﻿RESEARCH ARTICLE Incidence of Neuralgic Amyot...
# 1  Gastrointestinal LCH: a rare manifestation of ...
# 2  Synovial Sarcoma: A Clinical Review\n\nby Aaro...
# 3  Interactions of the Human Pathogenic Brucella ...
# 4  Unilateral adrenal metastases as an unusual pr...

# %%
print(data.iloc[0]['content'])
# Out:
# RESEARCH ARTICLE Incidence of Neuralgic Amyotrophy (Parsonage Turner Syndrome) in a Primary Care Setting - A Prospective Cohort Study Nens van Alfen1* Jeroen J J van Eijk2 Tessa Ennik3 Sean O Flynn4 Inge E G Nobacht5 Jan T Groothuis6 Sigrid Pillen7 Floris A van de Laar8 Department of Neurology Donders Centre for Neuroscience Radboud university medical centre Nijmegen The Netherlands Department of Neurology Jeroen Bosch Hospital Den Bosch The Netherlands Department of Neurology Erasmus Medical Center Rotterdam The Netherlands Royal College of Surgeons in Ireland Dublin Ireland Primary Health Centre Oosterhout Nijmegen The Netherlands Department of Rehabilitation Donders Centre for Neuroscience Radboud university medical centre Nijmegen The Netherlands Department of Neurology Canisius Wilhelmina Hospital Nijmegen The Netherlands Department of Primary and Community Care Radboud Institute for Health Sciences Radboud university medical centre The Netherlands & Academic Health Centre Thermion Lent The Netherlands * nensvanalfen@radboudumcnl OPEN ACCESS Citation: van Alfen N van Eijk JJJ Ennik T Flynn SO Nobacht IEG Groothuis JT et al () Abstract Incidence of Neuralgic Amyotrophy (Parsonage Turner Syndrome) in a Primary Care Setting - A Prospective Cohort Study PLoS ONE (): e0128361 doi:/journalpone Objective Academic Editor: Claudia Sommer University of Neuralgic amyotrophy is considered a rare peripheral nervous system disorder but in prac- Würzburg GERMANY tice seems grossly under recognized which negatively affects care for these patients In Received: January this study we prospectively counted the one-year incidence rate of classic neuralgic amyo- Accepted: April trophy in a primary care setting Published: May Copyright: © van Alfen et al This is an open Methods access article distributed under the terms of the Creative Commons Attribution License which permits In a prospective cohort study during the year we registered all new cases of neck unrestricted use distribution and reproduction in any shoulder or arm complaints from two large primary care centers serving a population of medium provided the original author and source are Prior to study general practitioners received a short training on how to diagnose credited classic neuralgic amyotrophy Neuralgic amyotrophy was defined according to published Data Availability Statement: No centralized data criteria irrespective of family history Only patients with a classic phenotype were counted collection was available for this study Data were as definite cases After inclusion patients with suspected neuralgic amyotrophy who had collected in an anonymized digital datafile and stored locally by the study group The primary data file for not yet seen a neurologist were offered neurologic evaluation for diagnostic confirmation this study is available as S1 Datafile Funding: This study was sponsored by an unsolicited and unconditional gift from the Dutch Rare Results Diseases Fund (Stichting Zeldzame Ziekten Fonds; Of the patients identified with new onset neck shoulder or arm complaints were wwwzzfnl) and the ZABAWAS Foundation (www suspected of having neuralgic amyotrophy After neurologic evaluation the diagnosis was zabawasnl) The funders had no role in study design data collection and analysis decision to publish or confirmed in patients This amounts to a one-year incidence rate for classic neuralgic preparation of the manuscript amyotrophy of per PLOS ONE | DOI:/journalpone May / Prospective Incidence of Neuralgic Amyotrophy Competing Interests: The authors have declared Conclusions that no competing interests exist Our findings suggest that neuralgic amyotrophy is - times more common than previ- ously thought Unawareness of the disorder and its clinical presentation seems the most likely explanation for this difference An incidence rate of per and the long-term se- quelae many patients suffer warrant more vigilance in diagnosing the disorder to pave the way for timely treatment and ...

# %% [markdown]
# <H1>Tokenisation with Stop Word Removal</H1>

# %%
def tokenize_text(text):
    # Convert to lowercase (ASCII is different)
    text = text.lower()
    # Remove newlines
    text = text.replace('\n', ' ')
    # Remove special characters like © and non-breaking spaces (shows up as NBSP)
    text = text.replace('©', '').replace('\u00A0', ' ')
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    # Remove references in square brackets
    text = re.sub(r'\[.*?\]', '', text)
    # Tokenise
    words = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    
    filtered_words = [
        word for word in words
        if word not in stop_words  # Remove stopwords
        and len(word) > 2         # Remove two-letter words
        and not any(char in word for char in ['β', 'α', 'µ', 'δ', 'γ'])  # Remove words that include these characters
        and not (word.isdigit() and len(word) > 4)  # Remove numbers longer than 4 digits
        and not (word.isdigit() and len(word) == 3)  # Remove numbers that are 3 digits long
        and not (len(word) == 4 and word.isdigit() and word[0] != '2')  # Remove 4-digit numbers not starting with '2' i.e. not recent dates, usually page numbers
        and not re.search(r'^[a-zA-Z]*\d+[a-zA-Z]+|[a-zA-Z]+\d+[a-zA-Z]*$', word)  # Remove words that mix letters and digits
        ]
    
    return filtered_words

# %%
tokenized_data = data.copy()
tokenized_data["tokens"] = tokenized_data['content'].astype(str).apply(tokenize_text)
tokenized_data.drop(columns=['content'], inplace=True)

# %%
tokenized_data.head()
# Out:
#                                                title  \
# 0  Predisposing factors for incomplete spontaneou...
# 1  Gastrointestinal LCH a rare manifestation of L...
# 2  A rare case report of omental synovial sarcoma...
# 3  Chronic brucellosis with sacroiliitis A case r...
# 4  Unilateral adrenal metastases as an unusual pr...
#
#                                               tokens
# 0  [research, article, incidence, neuralgic, amyo...
# 1  [gastrointestinal, lch, rare, manifestation, l...
# 2  [synovial, sarcoma, clinical, review, aaron, g...
# 3  [interactions, human, pathogenic, brucella, sp...
# 4  [unilateral, adrenal, metastases, unusual, pri...

# %%
print(tokenized_data['tokens'].iloc[0])
# Out:
# ['research', 'article', 'incidence', 'neuralgic', 'amyotrophy', 'parsonage', 'turner', 'syndrome', 'primary', 'care', 'setting', 'prospective', 'cohort', 'study', 'nens', 'van', 'jeroen', 'van', 'tessa', 'sean', 'inge', 'jan', 'sigrid', 'floris', 'van', 'department', 'neurology', 'donders', 'centre', 'neuroscience', 'radboud', 'university', 'medical', 'centre', 'nijmegen', 'netherlands', 'department', 'neurology', 'jeroen', 'bosch', 'hospital', 'den', 'bosch', 'netherlands', 'department', 'neurology', 'erasmus', 'medical', 'center', 'rotterdam', 'netherlands', 'royal', 'college', 'surgeons', 'ireland', 'dublin', 'ireland', 'primary', 'health', 'centre', 'oosterhout', 'nijmegen', 'netherlands', 'department', 'rehabilitation', 'donders', 'centre', 'neuroscience', 'radboud', 'university', 'medical', 'centre', 'nijmegen', 'netherlands', 'department', 'neurology', 'canisius', 'wilhelmina', 'hospital', 'nijmegen', 'netherlands', 'department', 'primary', 'community', 'care', 'radboud', 'institute', 'health', 'sciences', 'radboud', 'university', 'medical', 'centre', 'netherlands', 'academic', 'health', 'centre', 'thermion', 'lent', 'netherlands', 'nensvanalfenradboudumcnl', 'open', 'access', 'citation', 'van', 'alfen', 'van', 'eijk', 'jjj', 'ennik', 'flynn', 'nobacht', 'ieg', 'groothuis', 'abstract', 'incidence', 'neuralgic', 'amyotrophy', 'parsonage', 'turner', 'syndrome', 'primary', 'care', 'setting', 'prospective', 'cohort', 'study', 'plos', 'one', 'doijournalpone', 'objective', 'academic', 'editor', 'claudia', 'sommer', 'university', 'neuralgic', 'amyotrophy', 'considered', 'rare', 'peripheral', 'nervous', 'system', 'disorder', 'prac', 'würzburg', 'germany', 'tice', 'seems', 'grossly', 'recognized', 'negatively', 'affects', 'care', 'patients', 'received', 'january', 'study', 'prospectively', 'counted', 'oneyear', 'incidence', 'rate', 'classic', 'neuralgic', 'amyo', 'accepted', 'april', 'trophy', 'primary', 'care', 'setting', 'published', 'may', 'copyright', 'van', 'alfen', 'open', 'methods', 'access', 'article', 'distributed', 'terms', 'creative', 'commons', 'attribution', 'license', 'permits', 'prospective', 'cohort', 'study', 'year', 'registered', 'new', 'cases', 'neck', 'unrestricted', 'use', 'distribution', 'reproduction', 'shoulder', 'arm', 'complaints', 'two', 'large', 'primary', 'care', 'centers', 'serving', 'population', 'medium', 'provided', 'original', 'author', 'source', 'prior', 'study', 'general', 'practitioners', 'received', 'short', 'training', 'diagnose', 'credited', 'classic', 'neuralgic', 'amyotrophy', 'neuralgic', 'amyotrophy', 'defined', 'according', 'published', 'data', 'availability', 'statement', 'centralized', 'data', 'criteria', 'irrespective', 'family', 'history', 'patients', 'classic', 'phenotype', 'counted', 'collection', 'available', 'study', 'data', 'definite', 'cases', 'inclusion', 'patients', 'suspected', 'neuralgic', 'amyotrophy', 'collected', 'anonymized', 'digital', 'datafile', 'stored', 'locally', 'study', 'group', 'primary', 'data', 'file', 'yet', 'seen', 'neurologist', 'offered', 'neurologic', 'evaluation', 'diagnostic', 'confirmation', 'study', 'available', 'datafile', 'funding', 'study', 'sponsored', 'unsolicited', 'unconditional', 'gift', 'dutch', 'rare', 'results', 'diseases', 'fund', 'stichting', 'zeldzame', 'ziekten', 'fonds', 'patients', 'identified', 'new', 'onset', 'neck', 'shoulder', 'arm', 'complaints', 'wwwzzfnl', 'zabawas', 'foundation', 'www', 'suspected', 'neuralgic', 'amyotrophy', 'neurologic', 'evaluation', 'diagnosis', 'zabawasnl', 'funders', 'role', 'study', 'design', 'data', 'collection', 'analysis', 'decision', 'publish', 'confirmed', 'patients', 'amounts', 'oneyear', 'incidence', 'rate', 'classic', 'neuralgic', 'preparation', 'manuscript', 'amyotrophy', 'per', 'plos', 'one', 'doijournalpone', 'may', 'prospective', 'incidence', 'neuralgic', 'amyotrophy', 'competing', 'interests', 'authors', 'declared', 'conclusions', 'competing', 'interests', 'exist', 'findings', 'suggest' ...

# %% [markdown]
# <H1>Lemmatize</H1>

# %%
def lemmatize_words(words):
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word, pos='n') for word in words]  # Lemmatize as nouns
    return lemmatized_words

# %%
lemmatized_data = tokenized_data.copy()
lemmatized_data["tokens_lemmatized"] = lemmatized_data["tokens"].apply(lambda x: lemmatize_words(x))
lemmatized_data["text_for_tfidf"] = lemmatized_data["tokens_lemmatized"].apply(lambda x: ' '.join(x))

# %%
lemmatized_data.head()
# Out:
#                                                title  \
# 0  Predisposing factors for incomplete spontaneou...
# 1  Gastrointestinal LCH a rare manifestation of L...
# 2  A rare case report of omental synovial sarcoma...
# 3  Chronic brucellosis with sacroiliitis A case r...
# 4  Unilateral adrenal metastases as an unusual pr...
#
#                                               tokens  \
# 0  [research, article, incidence, neuralgic, amyo...
# 1  [gastrointestinal, lch, rare, manifestation, l...
# 2  [synovial, sarcoma, clinical, review, aaron, g...
# 3  [interactions, human, pathogenic, brucella, sp...
# 4  [unilateral, adrenal, metastases, unusual, pri...
#
#                                    tokens_lemmatized  \
# 0  [research, article, incidence, neuralgic, amyo...
# 1  [gastrointestinal, lch, rare, manifestation, l...
# 2  [synovial, sarcoma, clinical, review, aaron, g...
# 3  [interaction, human, pathogenic, brucella, spe...
# 4  [unilateral, adrenal, metastasis, unusual, pri...
#
#                                       text_for_tfidf
# 0  research article incidence neuralgic amyotroph...
# 1  gastrointestinal lch rare manifestation langer...
# 2  synovial sarcoma clinical review aaron gazenda...
# 3  interaction human pathogenic brucella specie h...
# 4  unilateral adrenal metastasis unusual primary ...

# %%
print(lemmatized_data['tokens_lemmatized'].iloc[0])
# Out:
# ['research', 'article', 'incidence', 'neuralgic', 'amyotrophy', 'parsonage', 'turner', 'syndrome', 'primary', 'care', 'setting', 'prospective', 'cohort', 'study', 'nens', 'van', 'jeroen', 'van', 'tessa', 'sean', 'inge', 'jan', 'sigrid', 'floris', 'van', 'department', 'neurology', 'donders', 'centre', 'neuroscience', 'radboud', 'university', 'medical', 'centre', 'nijmegen', 'netherlands', 'department', 'neurology', 'jeroen', 'bosch', 'hospital', 'den', 'bosch', 'netherlands', 'department', 'neurology', 'erasmus', 'medical', 'center', 'rotterdam', 'netherlands', 'royal', 'college', 'surgeon', 'ireland', 'dublin', 'ireland', 'primary', 'health', 'centre', 'oosterhout', 'nijmegen', 'netherlands', 'department', 'rehabilitation', 'donders', 'centre', 'neuroscience', 'radboud', 'university', 'medical', 'centre', 'nijmegen', 'netherlands', 'department', 'neurology', 'canisius', 'wilhelmina', 'hospital', 'nijmegen', 'netherlands', 'department', 'primary', 'community', 'care', 'radboud', 'institute', 'health', 'science', 'radboud', 'university', 'medical', 'centre', 'netherlands', 'academic', 'health', 'centre', 'thermion', 'lent', 'netherlands', 'nensvanalfenradboudumcnl', 'open', 'access', 'citation', 'van', 'alfen', 'van', 'eijk', 'jjj', 'ennik', 'flynn', 'nobacht', 'ieg', 'groothuis', 'abstract', 'incidence', 'neuralgic', 'amyotrophy', 'parsonage', 'turner', 'syndrome', 'primary', 'care', 'setting', 'prospective', 'cohort', 'study', 'plo', 'one', 'doijournalpone', 'objective', 'academic', 'editor', 'claudia', 'sommer', 'university', 'neuralgic', 'amyotrophy', 'considered', 'rare', 'peripheral', 'nervous', 'system', 'disorder', 'prac', 'würzburg', 'germany', 'tice', 'seems', 'grossly', 'recognized', 'negatively', 'affect', 'care', 'patient', 'received', 'january', 'study', 'prospectively', 'counted', 'oneyear', 'incidence', 'rate', 'classic', 'neuralgic', 'amyo', 'accepted', 'april', 'trophy', 'primary', 'care', 'setting', 'published', 'may', 'copyright', 'van', 'alfen', 'open', 'method', 'access', 'article', 'distributed', 'term', 'creative', 'common', 'attribution', 'license', 'permit', 'prospective', 'cohort', 'study', 'year', 'registered', 'new', 'case', 'neck', 'unrestricted', 'use', 'distribution', 'reproduction', 'shoulder', 'arm', 'complaint', 'two', 'large', 'primary', 'care', 'center', 'serving', 'population', 'medium', 'provided', 'original', 'author', 'source', 'prior', 'study', 'general', 'practitioner', 'received', 'short', 'training', 'diagnose', 'credited', 'classic', 'neuralgic', 'amyotrophy', 'neuralgic', 'amyotrophy', 'defined', 'according', 'published', 'data', 'availability', 'statement', 'centralized', 'data', 'criterion', 'irrespective', 'family', 'history', 'patient', 'classic', 'phenotype', 'counted', 'collection', 'available', 'study', 'data', 'definite', 'case', 'inclusion', 'patient', 'suspected', 'neuralgic', 'amyotrophy', 'collected', 'anonymized', 'digital', 'datafile', 'stored', 'locally', 'study', 'group', 'primary', 'data', 'file', 'yet', 'seen', 'neurologist', 'offered', 'neurologic', 'evaluation', 'diagnostic', 'confirmation', 'study', 'available', 'datafile', 'funding', 'study', 'sponsored', 'unsolicited', 'unconditional', 'gift', 'dutch', 'rare', 'result', 'disease', 'fund', 'stichting', 'zeldzame', 'ziekten', 'fonds', 'patient', 'identified', 'new', 'onset', 'neck', 'shoulder', 'arm', 'complaint', 'wwwzzfnl', 'zabawas', 'foundation', 'www', 'suspected', 'neuralgic', 'amyotrophy', 'neurologic', 'evaluation', 'diagnosis', 'zabawasnl', 'funders', 'role', 'study', 'design', 'data', 'collection', 'analysis', 'decision', 'publish', 'confirmed', 'patient', 'amount', 'oneyear', 'incidence', 'rate', 'classic', 'neuralgic', 'preparation', 'manuscript', 'amyotrophy', 'per', 'plo', 'one', 'doijournalpone', 'may', 'prospective', 'incidence', 'neuralgic', 'amyotrophy', 'competing', 'interest', 'author', 'declared', 'conclusion', 'competing', 'interest', 'exist', 'finding', 'suggest', 'neuralgic', 'amyotrophy' ...

# %% [markdown]
# <H1>Apply TF-IDF</H1>

# %%
def apply_tfidf(dataframe):
    # Initialize TF-IDF Vectorizer with tokens as input
    vectorizer = TfidfVectorizer(analyzer=lambda x: x)
    # Fit and transform the tokenized content to a TF-IDF matrix
    tfidf_matrix = vectorizer.fit_transform(dataframe['tokens_lemmatized'])
    # Convert the matrix to a DataFrame for easier viewing
    result = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
    return result, vectorizer

# %%
tfidf_df, tfidf_vectorizer = apply_tfidf(lemmatized_data)

# %%
tfidf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Columns: 11622 entries, 2000 to μgμl
# dtypes: float64(11622)
# memory usage: 4.3 MB

# %% [markdown]
# <H1>Create the Inverted Index</H1>

# %%
def create_inverted_index_from_tfidf(tfidf_df, tokenized_data):
    # Step 1: Create a term dictionary (unique terms to termID mapping)
    terms = tfidf_df.columns
    term_dict = {idx: term for idx, term in enumerate(terms)}  # termID -> term

    # Initialize list to build the inverted index
    inverted_index = []

    # Step 2: Build the inverted index (termID, docID, freq, tf-idf, positions)
    for docID, tokens in enumerate(tokenized_data['tokens']):
        term_freq = {}  # term -> frequency in the document
        positions = {}  # term -> positions list
        
        for pos, term in enumerate(tokens):
            termID = next((k for k, v in term_dict.items() if v == term), None)  # Get termID for the term
            if termID is not None:  # If the term exists in the term_dict
                if termID not in term_freq:
                    term_freq[termID] = 0
                    positions[termID] = []
                term_freq[termID] += 1
                positions[termID].append(pos)

        # Add entries to the inverted index
        for termID, freq in term_freq.items():
            tfidf_score = tfidf_df.iloc[docID, termID]  # Get the TF-IDF score for the term in this document
            inverted_index.append({
                'termID': termID,
                'docID': docID,
                'freq': freq,
                'tf-idf': tfidf_score,
                'positions': positions[termID]
            })

    # Step 3: Create DataFrames for the results
    result_term_dict = pd.DataFrame(list(term_dict.items()), columns=['termID', 'term'])
    result_inverted_index = pd.DataFrame(inverted_index)

    return result_term_dict, result_inverted_index

# %%
# Usage:
term_dict_df, inverted_index_df = create_inverted_index_from_tfidf(tfidf_df, tokenized_data)

# %%
# Viewing the results
print("Term Dictionary:")
print(term_dict_df.head())
print("\nInverted Index:")
print(inverted_index_df.head())
# Out:
# Term Dictionary:
#    termID  term
# 0       0  2000
# 1       1  2001
# 2       2  2002
# 3       3  2007
# 4       4  2008
#
# Inverted Index:
#    termID  docID  freq   tf-idf  \
# 0    8914      0     4 0.013553
# 1     821      0     2 0.008380
# 2    5147      0    29 0.133620
# 3    6941      0    71 0.589395
# 4     528      0    68 0.564491
#
#                                            positions
# 0                               [0, 587, 1203, 1240]
# 1                                           [1, 180]
# 2  [2, 115, 161, 325, 338, 366, 539, 575, 597, 66...
# 3  [3, 116, 136, 164, 225, 227, 254, 306, 328, 33...
# 4  [4, 117, 137, 226, 228, 255, 307, 331, 340, 35...

# %% [markdown]
# <H1>Information Retrieval Model</H1>

# %% [markdown]
# ## Query processing

# %%
query = "tracheal rupture"

# %% [markdown]
# ps this is only to show, skip and  use the function directly

# %%
tokenized_query = tokenize_text(query)
print(tokenized_query)
# Out:
# ['tracheal', 'rupture']

# %%
lemmatized_query = lemmatize_words(tokenized_query)
print(lemmatized_query)
# Out:
# ['tracheal', 'rupture']

# %%
def match_query_to_documents(query_string, tfidf_data, vectorizer, top_n=5):
    # Step 1: Preprocess the query
    processed_query = tokenize_text(query_string)
    processed_query = lemmatize_words(processed_query)
    
    # Step 2: Transform the query into the same TF-IDF space as documents
    query_tfidf = vectorizer.transform([processed_query])  # Query as a 1xN vector    
    if np.count_nonzero(query_tfidf.toarray()) == 0:
        print("Query vector is zero. Check query preprocessing.")
        return
    
    # Step 3: Compute cosine similarity between query and documents
    cosine_sim = cosine_similarity(query_tfidf, tfidf_data)
    
    # Step 4: Get the most similar document(s)
    similarity_scores = cosine_sim.flatten()
    top_indices = similarity_scores.argsort()[-top_n:][::-1]  # Get indices of top N scores (descending order)
    top_scores = similarity_scores[top_indices]  # Corresponding scores
    
    return top_indices, top_scores

# %%
top_indices, top_scores = match_query_to_documents(query, tfidf_df, tfidf_vectorizer, top_n=5)

# %%
print("Top 5 matching documents:")
for idx, score in zip(top_indices, top_scores):
    print(f"Document Title: {data.iloc[idx]['title']}, Similarity Score: {score}")
# Out:
# Top 5 matching documents:
# Document Title: Post-intubation tracheal rupture treated surgically using a muscle graft from the Latissimus Dorsi a rare disorder and review of literature., Similarity Score: 0.4574559477073631
# Document Title: False-Negative Motor-Evoked Potential Due to Contrast-Induced Encephalopathy During Coil Embolization for Intracranial Aneurysm A Case Report, Similarity Score: 0.012575161053957735
# Document Title: Repair of an iatrogenic lacrimal fistula a case report, Similarity Score: 0.009683871731696266
# Document Title: Endocrine disorders in Rett syndrome a systematic review of the literature, Similarity Score: 0.0
# Document Title: Report of one case with de novo mutation in TLK2 and literature review, Similarity Score: 0.0

# %%
term_dict_df.to_csv("term_dict.csv", index=False)
inverted_index_df.to_csv("inverted_index.csv", index=False)

# %%
doc_list = tokenized_data.drop(columns=['tokens'])
doc_list.to_csv("doc_list.csv", index=True)

# %% [markdown]
# <h1>Tables</h1>

# %%
# Connecter à PostgreSQL
def create_connection():
    try:
        conn = psycopg2.connect(
            dbname="documents", 
            user="avnadmin", 
            password="AVNS_l7Jb2H8TcLKMke_Jm_j", 
            host="pg-328cb18b-hamdounechaymae-7b98.h.aivencloud.com", 
            port="10809"
        )
        return conn
    except Exception as e:
        print(f"Erreur de connexion à la base de données: {e}")
        return None

# %%
def create_tables():
    commands = (
        """
        CREATE TABLE doc_list (
            id SERIAL PRIMARY KEY,
            title VARCHAR(255) NOT NULL
        )
        """,
        """
        CREATE TABLE term_dict (
            termID SERIAL PRIMARY KEY,
            term VARCHAR(255) NOT NULL
        )
        """,
        """
        CREATE TABLE inverted_index (
            termID INT,
            docID INT,
            freq INT,
            tf_idf FLOAT,
            positions TEXT,
            FOREIGN KEY (termID) REFERENCES term_dict(termID),
            FOREIGN KEY (docID) REFERENCES doc_list(id)
        )
        """
    )
    conn = create_connection()
    if conn is not None:
        try:
            cur = conn.cursor()
            for command in commands:
                cur.execute(command)
            cur.close()
            conn.commit()
        except Exception as e:
            print(f"Erreur lors de la création des tables: {e}")
        finally:
            conn.close()
    else:
        print("Erreur de connexion à la base de données.")

# %%
create_tables()

# %%
def check_tables():
    conn = create_connection()
    if conn is not None:
        try:
            cur = conn.cursor()
            cur.execute("""
                SELECT table_name 
                FROM information_schema.tables 
                WHERE table_schema = 'public'
            """)
            tables = cur.fetchall()
            print("Tables in the database:")
            for table in tables:
                print(table[0])
            cur.close()
        except Exception as e:
            print(f"Erreur lors de la vérification des tables: {e}")
        finally:
            conn.close()
    else:
        print("Erreur de connexion à la base de données.")

# Appeler la fonction pour vérifier les tables
check_tables()
# Out:
# Tables in the database:
# doc_list
# inverted_index
# term_dict

# %%
def insert_data_from_csv(table_name, csv_file_path):
    conn = create_connection()
    if conn is not None:
        try:
            cur = conn.cursor()
            with open(csv_file_path, 'r') as f:
                next(f)  # Skip the header row
                cur.copy_expert(f"COPY {table_name} FROM STDIN WITH CSV HEADER", f)
            conn.commit()
            cur.close()
            print(f"Data inserted into {table_name} from {csv_file_path}")
        except Exception as e:
            print(f"Erreur lors de l'insertion des données: {e}")
        finally:
            conn.close()
    else:
        print("Erreur de connexion à la base de données.")

# %%
# def insert_into_doc_list(id, title):
#     conn = create_connection()
#     if conn is not None:
#         try:
#             cur = conn.cursor()
#             cur.execute("INSERT INTO doc_list (id, title) VALUES (%s, %s)", (id, title))
#             conn.commit()
#             cur.close()
#             print(f"Inserted into doc_list: ({id}, {title})")
#         except Exception as e:
#             print(f"Erreur lors de l'insertion dans doc_list: {e}")
#         finally:
#             conn.close()
#     else:
#         print("Erreur de connexion à la base de données.")

# def insert_into_term_dict(termID, term):
#     conn = create_connection()
#     if conn is not None:
#         try:
#             cur = conn.cursor()
#             cur.execute("INSERT INTO term_dict (termID, term) VALUES (%s, %s)", (termID, term))
#             conn.commit()
#             cur.close()
#             print(f"Inserted into term_dict: ({termID}, {term})")
#         except Exception as e:
#             print(f"Erreur lors de l'insertion dans term_dict: {e}")
#         finally:
#             conn.close()
#     else:
#         print("Erreur de connexion à la base de données.")

# # Insert data into doc_list
# insert_into_doc_list(0, "Predisposing factors for incomplete spontaneous recovery after Parsonage-Turner Syndrome.")

# # Insert data into term_dict
# insert_into_term_dict(0, "2000")
# Out:
# Inserted into doc_list: (0, Predisposing factors for incomplete spontaneous recovery after Parsonage-Turner Syndrome.)
# Inserted into term_dict: (0, 2000)

# %%
insert_data_from_csv('doc_list', './doc_list.csv')
insert_data_from_csv('term_dict', './term_dict.csv')
insert_data_from_csv('inverted_index', './inverted_index.csv')
# Out:
# Data inserted into inverted_index from ./inverted_index.csv

# %%
def check_table_contents(table_name):
    conn = create_connection()
    if conn is not None:
        try:
            cur = conn.cursor()
            cur.execute(f"SELECT * FROM {table_name}")
            rows = cur.fetchall()
            print(f"Contents of {table_name}:")
            for row in rows:
                print(row)
            cur.close()
        except Exception as e:
            print(f"Erreur lors de la vérification des contenus de la table {table_name}: {e}")
        finally:
            conn.close()
    else:
        print("Erreur de connexion à la base de données.")

# Example usage
check_table_contents('doc_list')
check_table_contents('term_dict')
check_table_contents('inverted_index')
# Out:
# Contents of doc_list:
# (1, 'Gastrointestinal LCH a rare manifestation of Langerhans cell histiocytosis')
# (2, 'A rare case report of omental synovial sarcoma complicated hemoperitoneum and literature review')
# (3, 'Chronic brucellosis with sacroiliitis A case report')
# (4, 'Unilateral adrenal metastases as an unusual primary presentation of hepatocellular carcinoma a case report and literature review')
# (5, 'Repair of an iatrogenic lacrimal fistula a case report')
# (6, 'Cutaneous Metastasis of Breast Carcinoma in the Distal Phalanx of the Left Little Finger A Case Report')
# (7, 'Spontaneous cerebrospinal fluid rhinorrhoea a case report and literature review')
# (8, 'SIADH secondary to rhino-orbito-cerebral mucormycosis A case report')
# (9, 'Genetic and Cellular Basis of Impai.tx24- Genetic and Cellular Basis of Impaired Phagocytosis and Photoreceptor Degeneration in CLN3 Disease')
# (10, 'Aseptic Meningitis as an Initial Presentation of Primary Sjogren Syndrome A Case Report')
# (11, 'Uncommon site of Brucella endocarditis in a double discordant heart')
# (12, 'Report of one case with de novo mutation in TLK2 and literature review')
# (13, 'False-Negative Motor-Evoked Potential Due to Contrast-Induced Encephalopathy During Coil Embolization for Intracranial Aneurysm A Case Report')
# (14, 'High Burden Ventricular Ectopy\u2009\u200910 in Children with Structurally Normal Hearts Investigating the Association of Ventricular Ectopy Frequency, Holter and ECG Findings, and Ventricular Dysfunction._removed')
# (15, 'A primary intracranial neuroepithelial neoplasm with novel TCF3BEND2 fusion a case report')
# (16, 'Successful treatment of a 4-year-old girl with pure malignant rhabdoid tumor of the bladder a case report')
# (17, 'Pediatric neurobrucellosis and atypical Guillain-Barre syndrome an intriguing case unveiled')
# (18, 'Case report orthostatic hypotension as the first presentation of progressive encephalomyelitis with rigidity and myoclonus (PERM) with multiple autoimmune antibodies')
# (19, 'The therapeutic potential of Apigenin in amyotrophic lateral sclerosis through ALDH1A2Nrf2ARE signaling')
# (20, 'A novel disease-causing variant associated with a milder phenotype of AARS2-related leukodystrophy - A case report')
# (21, 'Post-intubation tracheal rupture treated surgically using a muscle graft from the Latissimus Dorsi a rare disorder and review of literature.')
# (22, 'An Unusual Case of Early-onset Ankylosing Spondylitis with Predominant Cervical Spine Involvement')
# (23, 'Brain abscess caused by Streptococcus pyogenes with atypical symptoms a case report and literature review')
# (24, 'Ultrasound evaluation of kidney and liver involvement in Bardet-Biedl syndrome')
# (25, 'Case report Pediatric hepatopulmonary syndrome despite strict weight control after craniopharyngioma surgery')
# (26, 'Therapeutic effect of nimustine in a dog with intracranial histiocytic sarcoma')
# (27, 'Episodic Coma in Lewy Body Disorders An Observational Report')
# (28, 'Musculoskeletal infections associated with ')
# (29, 'Uncommon Coexistence of Eosinophilic Colitis, Asthma, and Elevated IgG4 Levels A Case Report')
# (30, 'Genome-wide meta-analysis of myasthenia gravis uncovers new loci and provides insights into polygenic prediction')
# (31, 'Genetic and Cellular Basis of Impaired Phagocytosis and Photoreceptor Degeneration in CLN3 Disease')
# (32, 'Locally acquired typhoid fever outbreak linked to chronic carriage in Ottawa, Canada, 2018-2022.')
# (33, 'Holocord syringomyelia caused by tethered cord syndrome case report and literature review._removed')
# (34, 'Initiation response, maximized therapeutic efficacy, and post-treatment effects of biological targeted therapies in myasthenia gravis a systematic review and network meta-analysis.')
# (35, 'Switching treatment to cipaglucosidase alfa plus miglustat positively affects patient-reported outcome measures in patients with late-onset Pompe disease')
# (36, 'A case of postpartum dermatomyositis with onset at three months expanding the clinical spectrum')
# (37, 'Musculoskeletal manifestations of lower-extremity coccidioidomycosis a case series.')
# (38, 'Brain and lung arteriovenous malformation rescreening practices for children and adults with hereditary hemorrhagic telangiectasia')
# (39, 'CNS histoplasmosis coexisting with pulmonary tuberculosis in a HIV negative patient case report')
# (40, 'Generation of human induced pluripotent stem cell lines derived from patients of cystic biliary atresia')
# (41, 'An Interesting Case of Weil_s Disease with Diagnostic Challenges')
# (42, "GNG5 is a novel regulator of Aβ42 production in Alzheimer's disease")
# (43, 'Adult-Onset Neuronal Ceroid Lipofuscinosis')
# (44, 'Chronic Granulomatous Invasive Fungal Rhinosinusitis With Intracranial Extension in an Immunocompetent Patient A Case Report')
# (45, 'Autoimmune encephalitis with coexisting antibodies to GABABR, GAD65, SOX1 and Ma2')
# (46, 'Association between tumor location and toxicity outcomes after stereotactic radiosurgery for brain metastases')
# (47, 'Endocrine disorders in Rett syndrome a systematic review of the literature')
# (0, 'Predisposing factors for incomplete spontaneous recovery after Parsonage-Turner Syndrome.')
# Contents of term_dict:
# (1, '2001')
# (2, '2002')
# (3, '2007')
# (4, '2008')
# (5, '2009')
# (6, '2010')
# (7, '2011')
# (8, '2012')
# (9, '2013')
# (10, '2014')
# (11, '2015')
# (12, '2016')
# (13, '2017')
# (14, '2018')
# (15, '2019')
# (16, '2020')
# (17, '2021')
# (18, '2022')
# (19, '2023')
# (20, '2024')
# (21, '2025')
# (22, '2029')
# (23, '2040')
# (24, '2122')
# (25, '2125')
# (26, '2126')
# (27, '2127')
# (28, '2148')
# (29, '2151')
# (30, '2157')
# (31, '2259')
# (32, '2343')
# (33, '2445')
# (34, '2449')
# (35, '2460')
# (36, '2500')
# (37, '2528')
# (38, '2546')
# (39, '2548')
# (40, '2549')
# (41, '2551')
# (42, '2561')
# (43, '2627')
# (44, '2630')
# (45, '2649')
# (46, '2747')
# (47, '2760')
# (48, '2831')
# (49, '2970')
# (50, 'aac')
# (51, 'aaleppo')
# (52, 'aan')
# (53, 'aaron')
# (54, 'aaþ')
# (55, 'ab')
# (56, 'abacavirdolutegravirlamivud')
# (57, 'abbate')
# (58, 'abbott')
# (59, 'abbreviation')
# (60, 'abc')
# (61, 'abcam')
# (62, 'abd')
# (63, 'abdomen')
# (64, 'abdomenpelvis')
# (65, 'abdominal')
# (66, 'abdominocentesis')
# (67, 'abdominopelvic')
# (68, 'abducens')
# (69, 'abduct')
# (70, 'abduction')
# (71, 'abductionanteflexion')
# (72, 'abductor')
# (73, 'abdul')
# (74, 'abdulaziz')
# (75, 'abdullah')
# (76, 'abdulmajid')
# (77, 'abdulmohsen')
# (78, 'aberrant')
# (79, 'aberrantly')
# (80, 'aberration')
# (81, 'abf')
# (82, 'ability')
# (83, 'ablative')
# (84, 'able')
# (85, 'abnormal')
# (86, 'abnormality')
# (87, 'abnormally')
# (88, 'abo')
# (89, 'abortus')
# (90, 'abrishamkar')
# (91, 'abruptly')
# (92, 'abscess')
# (93, 'abscessseptic')
# (94, 'abscessus')
# (95, 'absence')
# (96, 'absent')
# (97, 'absolute')
# (98, 'absolutely')
# (99, 'absorbable')
# (100, 'absorbance')
# (101, 'absorbed')
# (102, 'absorption')
# (103, 'abstract')
# (104, 'abundance')
# (105, 'abundant')
# (106, 'acaccatgggagcttggtaat')
# (107, 'academic')
# (108, 'academy')
# (109, 'acan')
# (110, 'accagcctcatgcacaacca')
# (111, 'accelerate')
# (112, 'accelerated')
# (113, 'accelerates')
# (114, 'accelerating')
# (115, 'acceptable')
# (116, 'acceptance')
# (117, 'accepted')
# (118, 'access')
# (119, 'accessed')
# (120, 'accessibility')
# (121, 'accessible')
# (122, 'accession')
# (123, 'accidental')
# (124, 'acclimated')
# (125, 'accom')
# (126, 'accompanied')
# (127, 'accompanying')
# (128, 'accordance')
# (129, 'according')
# (130, 'accordingly')
# (131, 'account')
# (132, 'accountable')
# (133, 'accounted')
# (134, 'accounting')
# (135, 'accredited')
# (136, 'accrual')
# (137, 'accrued')
# (138, 'accruing')
# (139, 'accu')
# (140, 'accumula')
# (141, 'accumulate')
# (142, 'accumulates')
# (143, 'accumulating')
# (144, 'accumulation')
# (145, 'accuracy')
# (146, 'accurate')
# (147, 'accurately')
# (148, 'accutase')
# (149, 'acerdemir')
# (150, 'acetabular')
# (151, 'acetaminophen')
# (152, 'acetate')
# (153, 'acetazolamide')
# (154, 'acetonitrile')
# (155, 'acetylcholine')
# (156, 'ach')
# (157, 'ache')
# (158, 'achieve')
# (159, 'achieved')
# (160, 'achievement')
# (161, 'achieves')
# (162, 'achieving')
# (163, 'achilles')
# (164, 'aching')
# (165, 'achr')
# (166, 'achrab')
# (167, 'achrabpositive')
# (168, 'achrmg')
# (169, 'acid')
# (170, 'acidfast')
# (171, 'acidified')
# (172, 'acidschiff')
# (173, 'acinetobacter')
# (174, 'acknowledge')
# (175, 'acknowledgement')
# (176, 'acknowledgment')
# (177, 'acmg')
# (178, 'acnu')
# (179, 'acoustic')
# (180, 'acquire')
# (181, 'acquired')
# (182, 'acquiring')
# (183, 'acquisi')
# (184, 'acquisition')
# (185, 'across')
# (186, 'act')
# (187, 'acteristics')
# (188, 'actin')
# (189, 'acting')
# (190, 'actinomycin')
# (191, 'action')
# (192, 'activate')
# (193, 'activated')
# (194, 'activating')
# (195, 'activation')
# (196, 'active')
# (197, 'activity')
# (198, 'actn')
# (199, 'actual')
# (200, 'acuity')
# (201, 'acute')
# (202, 'acutely')
# (203, 'acvp')
# (204, 'acyclovir')
# (205, 'adam')
# (206, 'adapt')
# (207, 'adaptation')
# (208, 'adapted')
# (209, 'adapter')
# (210, 'adc')
# (211, 'adcmap')
# (212, 'add')
# (213, 'added')
# (214, 'addgene')
# (215, 'addi')
# (216, 'adding')
# (217, 'addition')
# (218, 'additional')
# (219, 'additionally')
# (220, 'additive')
# (221, 'address')
# (222, 'addressed')
# (223, 'addressing')
# (224, 'adenine')
# (225, 'adenocarcinoma')
# (226, 'adenomatoid')
# (227, 'adenopathy')
# (228, 'adequate')
# (229, 'adequately')
# (230, 'adesha')
# (231, 'adh')
# (232, 'adhartighgmailcom')
# (233, 'adher')
# (234, 'adhered')
# (235, 'adherence')
# (236, 'adherent')
# (237, 'adhering')
# (238, 'adhesion')
# (239, 'adipose')
# (240, 'adjacent')
# (241, 'adjunct')
# (242, 'adjusted')
# (243, 'adjusting')
# (244, 'adjustment')
# (245, 'adjuvant')
# (246, 'adl')
# (247, 'administered')
# (248, 'administering')
# (249, 'administrated')
# (250, 'administration')
# (251, 'administrative')
# (252, 'admission')
# (253, 'admitted')
# (254, 'ado')
# (255, 'adolescence')
# (256, 'adolescent')
# (257, 'adopted')
# (258, 'adoptive')
# (259, 'adrelated')
# (260, 'adrenal')
# (261, 'adrenalectomy')
# (262, 'adrenocortical')
# (263, 'aducanumab')
# (264, 'adult')
# (265, 'adulthood')
# (266, 'adultonset')
# (267, 'advance')
# (268, 'advanced')
# (269, 'advancement')
# (270, 'advancing')
# (271, 'advantage')
# (272, 'adventitia')
# (273, 'adverse')
# (274, 'advice')
# (275, 'advisable')
# (276, 'advise')
# (277, 'advised')
# (278, 'advocacy')
# (279, 'advocate')
# (280, 'advocated')
# (281, 'aeautoimmune')
# (282, 'aerobic')
# (283, 'aerosolized')
# (284, 'aetiology')
# (285, 'afb')
# (286, 'afebrile')
# (287, 'affect')
# (288, 'affected')
# (289, 'affecting')
# (290, 'affiliated')
# (291, 'affiliation')
# (292, 'afghan')
# (293, 'aforementioned')
# (294, 'afp')
# (295, 'africa')
# (296, 'afte')
# (297, 'afterward')
# (298, 'agarose')
# (299, 'age')
# (300, 'ageadjusted')
# (301, 'ageappropriate')
# (302, 'aged')
# (303, 'agedependent')
# (304, 'ageing')
# (305, 'agematched')
# (306, 'agency')
# (307, 'agent')
# (308, 'agerelated')
# (309, 'agesex')
# (310, 'agespecific')
# (311, 'agey')
# (312, 'agglutination')
# (313, 'aggravate')
# (314, 'aggravated')
# (315, 'aggravates')
# (316, 'aggravating')
# (317, 'aggrecan')
# (318, 'aggregate')
# (319, 'aggregated')
# (320, 'aggregation')
# (321, 'aggression')
# (322, 'aggressive')
# (323, 'aging')
# (324, 'agnieszka')
# (325, 'agnosis')
# (326, 'ago')
# (327, 'agonist')
# (328, 'agree')
# (329, 'agreed')
# (330, 'agreement')
# (331, 'agrees')
# (332, 'agwasstratified')
# (333, 'ahmad')
# (334, 'ahmed')
# (335, 'aic')
# (336, 'aicd')
# (337, 'aid')
# (338, 'aiding')
# (339, 'aim')
# (340, 'aimed')
# (341, 'aiming')
# (342, 'air')
# (343, 'airway')
# (344, 'aishwarya')
# (345, 'ait')
# (346, 'ajcc')
# (347, 'ajinomoto')
# (348, 'akaike')
# (349, 'akashi')
# (350, 'akcimen')
# (351, 'akeely')
# (352, 'aki')
# (353, 'akihiko')
# (354, 'akin')
# (355, 'akinetic')
# (356, 'akram')
# (357, 'al')
# (358, 'ala')
# (359, 'alagille')
# (360, 'alal')
# (361, 'alanine')
# (362, 'alanyltransfer')
# (363, 'alaser')
# (364, 'alb')
# (365, 'albalawi')
# (366, 'albeit')
# (367, 'albekaai')
# (368, 'albendazole')
# (369, 'albicans')
# (370, 'albl')
# (371, 'albumin')
# (372, 'albuminocytological')
# (373, 'albuterol')
# (374, 'alc')
# (375, 'alcohol')
# (376, 'alcoholtobacco')
# (377, 'aldeeb')
# (378, 'aldehyde')
# (379, 'aldh')
# (380, 'aldosterone')
# (381, 'aldosteronerenin')
# (382, 'aldrich')
# (383, 'ale')
# (384, 'aleppo')
# (385, 'alert')
# (386, 'alerted')
# (387, 'alex')
# (388, 'alexa')
# (389, 'alexaconjugated')
# (390, 'alexafluorconjugated')
# (391, 'alexander')
# (392, 'alf')
# (393, 'alfa')
# (394, 'alfamiglustat')
# (395, 'alfen')
# (396, 'alfresa')
# (397, 'alfuwayris')
# (398, 'alg')
# (399, 'alglucosidase')
# (400, 'algorithm')
# (401, 'algouti')
# (402, 'algpbo')
# (403, 'algpboalglucosidase')
# (404, 'algplacebo')
# (405, 'alhamer')
# (406, 'alharshan')
# (407, 'ali')
# (408, 'aligned')
# (409, 'alignment')
# (410, 'alimentation')
# (411, 'alive')
# (412, 'alix')
# (413, 'alized')
# (414, 'alkaline')
# (415, 'alkaloid')
# (416, 'alkylating')
# (417, 'alkylation')
# (418, 'allele')
# (419, 'allelic')
# (420, 'allergen')
# (421, 'allergic')
# (422, 'allergy')
# (423, 'allergyimmunology')
# (424, 'allevi')
# (425, 'alleviate')
# (426, 'alleviated')
# (427, 'alleviating')
# (428, 'alleviation')
# (429, 'alliance')
# (430, 'allied')
# (431, 'allocation')
# (432, 'allow')
# (433, 'allowed')
# (434, 'allowing')
# (435, 'allows')
# (436, 'allvital')
# (437, 'ally')
# (438, 'almakhayitah')
# (439, 'almost')
# (440, 'almukhaitah')
# (441, 'alnaim')
# (442, 'alnajjar')
# (443, 'alone')
# (444, 'along')
# (445, 'alopecia')
# (446, 'alp')
# (447, 'alpert')
# (448, 'alphafetoprotein')
# (449, 'alphafetoproteinafp')
# (450, 'alphafold')
# (451, 'alphaglucosidase')
# (452, 'alphasynucleinopathy')
# (453, 'alrashdan')
# (454, 'already')
# (455, 'alscharacteristic')
# (456, 'also')
# (457, 'alsrelated')
# (458, 'alstdi')
# (459, 'alt')
# (460, 'alter')
# (461, 'alteration')
# (462, 'altered')
# (463, 'altering')
# (464, 'alternaria')
# (465, 'alternata')
# (466, 'alternate')
# (467, 'alternating')
# (468, 'alternative')
# (469, 'alters')
# (470, 'although')
# (471, 'altogether')
# (472, 'altr')
# (473, 'alugolu')
# (474, 'aluminum')
# (475, 'alveolararterial')
# (476, 'alveolus')
# (477, 'always')
# (478, 'alzheimers')
# (479, 'amaf')
# (480, 'amaxa')
# (481, 'amaximumcadd')
# (482, 'ambient')
# (483, 'ambulating')
# (484, 'ambulation')
# (485, 'ambulatory')
# (486, 'ameliorate')
# (487, 'ameliorated')
# (488, 'ameliorates')
# (489, 'ameliorating')
# (490, 'amenable')
# (491, 'amendment')
# (492, 'amenorrhea')
# (493, 'america')
# (494, 'american')
# (495, 'amg')
# (496, 'amikacin')
# (497, 'amino')
# (498, 'aminobutyrate')
# (499, 'aminobutyric')
# (500, 'aminotransferase')
# (501, 'amjad')
# (502, 'amman')
# (503, 'ammonis')
# (504, 'ammonium')
# (505, 'among')
# (506, 'amongst')
# (507, 'amount')
# (508, 'amoxicillinclavulanate')
# (509, 'amp')
# (510, 'ampel')
# (511, 'ampho')
# (512, 'amphotericin')
# (513, 'ample')
# (514, 'amplification')
# (515, 'amplified')
# (516, 'amplitaq')
# (517, 'amplitude')
# (518, 'amplitudespeak')
# (519, 'amputated')
# (520, 'amputation')
# (521, 'amxamoxicillin')
# (522, 'amygdala')
# (523, 'amyloid')
# (524, 'amyloidbeta')
# (525, 'amyo')
# (526, 'amyotro')
# (527, 'amyotrophic')
# (528, 'amyotrophy')
# (529, 'ana')
# (530, 'anaemia')
# (531, 'anaerobe')
# (532, 'anaerobic')
# (533, 'anal')
# (534, 'analgesic')
# (535, 'analog')
# (536, 'analogous')
# (537, 'analogue')
# (538, 'analy')
# (539, 'analysed')
# (540, 'analyser')
# (541, 'analysis')
# (542, 'analysisspecific')
# (543, 'analyze')
# (544, 'analyzed')
# (545, 'analyzing')
# (546, 'anatomic')
# (547, 'anatomical')
# (548, 'anatomically')
# (549, 'anatomy')
# (550, 'anca')
# (551, 'ance')
# (552, 'ancestral')
# (553, 'ancestry')
# (554, 'ancillary')
# (555, 'ancl')
# (556, 'ancova')
# (557, 'ancovaanalysis')
# (558, 'ancovas')
# (559, 'ancylostoma')
# (560, 'andatc')
# (561, 'andbetween')
# (562, 'andclose')
# (563, 'andmapped')
# (564, 'andmultiple')
# (565, 'andor')
# (566, 'andreas')
# (567, 'andwhole')
# (568, 'anemia')
# (569, 'anes')
# (570, 'anesthesia')
# (571, 'anesthesiologist')
# (572, 'anesthetic')
# (573, 'anesthetized')
# (574, 'aneurysm')
# (575, 'angelman')
# (576, 'angiogram')
# (577, 'angiographic')
# (578, 'angiographically')
# (579, 'angiography')
# (580, 'angiostrongylus')
# (581, 'angle')
# (582, 'anicteric')
# (583, 'animal')
# (584, 'anisokaryosis')
# (585, 'anja')
# (586, 'ankle')
# (587, 'ankleabd')
# (588, 'ankleedb')
# (589, 'ankylosing')
# (590, 'ankylosis')
# (591, 'ann')
# (592, 'anna')
# (593, 'annals')
# (594, 'annexin')
# (595, 'anno')
# (596, 'annotate')
# (597, 'annotated')
# (598, 'annotation')
# (599, 'annotationdependent')
# (600, 'annually')
# (601, 'anomaly')
# (602, 'anonymized')
# (603, 'anonymous')
# (604, 'anorexia')
# (605, 'another')
# (606, 'anova')
# (607, 'anserine')
# (608, 'answer')
# (609, 'answered')
# (610, 'antagonist')
# (611, 'antagoniste')
# (612, 'antecedent')
# (613, 'anteflect')
# (614, 'anteflexion')
# (615, 'antenatal')
# (616, 'anteri')
# (617, 'anterior')
# (618, 'anteriorly')
# (619, 'anteriorposterior')
# (620, 'anteroseptal')
# (621, 'anthony')
# (622, 'anthracyclinebased')
# (623, 'anthracyclines')
# (624, 'anthropometric')
# (625, 'anti')
# (626, 'antiafp')
# (627, 'antiallergic')
# (628, 'antiamphiphysin')
# (629, 'antiaphid')
# (630, 'antiapoptotic')
# (631, 'antibi')
# (632, 'antibiotic')
# (633, 'antibioticsmeared')
# (634, 'antibody')
# (635, 'antibodyassociated')
# (636, 'antibodybased')
# (637, 'antibodyclearing')
# (638, 'antibodymediated')
# (639, 'antibodyphenotypeswerenot')
# (640, 'antibodystratified')
# (641, 'antibrucella')
# (642, 'anticancer')
# (643, 'anticenpab')
# (644, 'anticipated')
# (645, 'anticoagulant')
# (646, 'anticonvulsant')
# (647, 'anticxcr')
# (648, 'anticyclic')
# (649, 'antidiuresis')
# (650, 'antidiuretic')
# (651, 'antidsdna')
# (652, 'antie')
# (653, 'antiemetic')
# (654, 'antiepileptic')
# (655, 'antifade')
# (656, 'antiflag')
# (657, 'antifun')
# (658, 'antifungal')
# (659, 'antigabab')
# (660, 'antigababr')
# (661, 'antigad')
# (662, 'antigen')
# (663, 'antigenic')
# (664, 'antigenpresenting')
# (665, 'antigenscca')
# (666, 'antiglutamic')
# (667, 'antiglycine')
# (668, 'antiglycineglyr')
# (669, 'antiglyr')
# (670, 'antiglyrrelated')
# (671, 'antigng')
# (672, 'antigoat')
# (673, 'antihemolysin')
# (674, 'antihistamine')
# (675, 'antihu')
# (676, 'antihypertensive')
# (677, 'antiimmunoglobulinlike')
# (678, 'antiinfection')
# (679, 'antiinflammatory')
# (680, 'antilassb')
# (681, 'antimicro')
# (682, 'antimicrobial')
# (683, 'antimouse')
# (684, 'antinanog')
# (685, 'antineurological')
# (686, 'antineuronal')
# (687, 'antineutrophil')
# (688, 'antinmda')
# (689, 'antinmdar')
# (690, 'antinucle')
# (691, 'antinuclear')
# (692, 'antioxidant')
# (693, 'antips')
# (694, 'antipsychotic')
# (695, 'antirab')
# (696, 'antirabbit')
# (697, 'antiretroviral')
# (698, 'antiri')
# (699, 'antirossa')
# (700, 'antisma')
# (701, 'antitb')
# (702, 'antitr')
# (703, 'antituberculosis')
# (704, 'antitumor')
# (705, 'antiyo')
# (706, 'antoine')
# (707, 'antonio')
# (708, 'antony')
# (709, 'antozzi')
# (710, 'anxiety')
# (711, 'anxietylike')
# (712, 'anywhere')
# (713, 'aorta')
# (714, 'aortic')
# (715, 'aoyama')
# (716, 'apart')
# (717, 'apathetic')
# (718, 'apathy')
# (719, 'apex')
# (720, 'apg')
# (721, 'apgs')
# (722, 'apgtreated')
# (723, 'apha')
# (724, 'aphasia')
# (725, 'aphthous')
# (726, 'apical')
# (727, 'apically')
# (728, 'apigenin')
# (729, 'aplio')
# (730, 'apoptosis')
# (731, 'apoptosisrelated')
# (732, 'apoptotic')
# (733, 'app')
# (734, 'apparatus')
# (735, 'apparent')
# (736, 'apparently')
# (737, 'appear')
# (738, 'appearance')
# (739, 'appeared')
# (740, 'appearing')
# (741, 'appears')
# (742, 'appendectomy')
# (743, 'appetite')
# (744, 'applica')
# (745, 'applicability')
# (746, 'applicable')
# (747, 'application')
# (748, 'applied')
# (749, 'applies')
# (750, 'apply')
# (751, 'appoe')
# (752, 'appointment')
# (753, 'appreciate')
# (754, 'approach')
# (755, 'approached')
# (756, 'appropriate')
# (757, 'appropriately')
# (758, 'appropriateness')
# (759, 'approval')
# (760, 'approved')
# (761, 'approx')
# (762, 'approxi')
# (763, 'approximate')
# (764, 'approximately')
# (765, 'approximation')
# (766, 'apps')
# (767, 'appswepsende')
# (768, 'april')
# (769, 'aptrcc')
# (770, 'apy')
# (771, 'aqueous')
# (772, 'arab')
# (773, 'arabia')
# (774, 'arcade')
# (775, 'arch')
# (776, 'architecture')
# (777, 'area')
# (778, 'areached')
# (779, 'aredriven')
# (780, 'areflexia')
# (781, 'arena')
# (782, 'arent')
# (783, 'arfaj')
# (784, 'arg')
# (785, 'arginase')
# (786, 'arise')
# (787, 'arises')
# (788, 'arising')
# (789, 'arithmetic')
# (790, 'arizona')
# (791, 'arm')
# (792, 'armonk')
# (793, 'around')
# (794, 'arouse')
# (795, 'arranged')
# (796, 'arrangement')
# (797, 'array')
# (798, 'arrb')
# (799, 'arrest')
# (800, 'arrhizus')
# (801, 'arrhythmia')
# (802, 'arrival')
# (803, 'arrived')
# (804, 'arrow')
# (805, 'arrowed')
# (806, 'arrowhead')
# (807, 'arterial')
# (808, 'arteriosus')
# (809, 'arteriovenous')
# (810, 'artery')
# (811, 'arthralgia')
# (812, 'arthritis')
# (813, 'arthro')
# (814, 'arthrocentesis')
# (815, 'arthrode')
# (816, 'arthrodesis')
# (817, 'arthropathy')
# (818, 'arthroplasty')
# (819, 'arthroscopic')
# (820, 'arthrotomy')
# (821, 'article')
# (822, 'articlesupplementary')
# (823, 'articular')
# (824, 'articulating')
# (825, 'artifact')
# (826, 'artificial')
# (827, 'arun')
# (828, 'asada')
# (829, 'asahi')
# (830, 'ascaris')
# (831, 'ascended')
# (832, 'ascending')
# (833, 'ascertain')
# (834, 'ascertained')
# (835, 'ascertainment')
# (836, 'asd')
# (837, 'aseptate')
# (838, 'aseptic')
# (839, 'ashok')
# (840, 'asia')
# (841, 'asian')
# (842, 'aside')
# (843, 'asked')
# (844, 'asking')
# (845, 'asks')
# (846, 'asleep')
# (847, 'asp')
# (848, 'aspartate')
# (849, 'aspect')
# (850, 'aspergillosis')
# (851, 'aspergillus')
# (852, 'aspirate')
# (853, 'aspirated')
# (854, 'aspiration')
# (855, 'aspirin')
# (856, 'aspredominant')
# (857, 'assadi')
# (858, 'assay')
# (859, 'assayed')
# (860, 'assemble')
# (861, 'assembled')
# (862, 'assembly')
# (863, 'assess')
# (864, 'assessed')
# (865, 'assesses')
# (866, 'assessing')
# (867, 'assessment')
# (868, 'assigned')
# (869, 'assigning')
# (870, 'assignment')
# (871, 'assist')
# (872, 'assistance')
# (873, 'associ')
# (874, 'associa')
# (875, 'associate')
# (876, 'associated')
# (877, 'associatedwith')
# (878, 'association')
# (879, 'assume')
# (880, 'assumed')
# (881, 'assuming')
# (882, 'assumption')
# (883, 'assured')
# (884, 'ast')
# (885, 'asterisk')
# (886, 'asthma')
# (887, 'asthmatic')
# (888, 'astroblastic')
# (889, 'astroblastoma')
# (890, 'astroblastomalike')
# (891, 'astroblastomas')
# (892, 'astrocyte')
# (893, 'aswell')
# (894, 'asymmetric')
# (895, 'asymmetrical')
# (896, 'asymmetrically')
# (897, 'asymmetry')
# (898, 'asymp')
# (899, 'asymptomatic')
# (900, 'ataxia')
# (901, 'atc')
# (902, 'atcagggccaagacatagagatg')
# (903, 'ate')
# (904, 'ated')
# (905, 'atgaaggggcagagacatca')
# (906, 'athlete')
# (907, 'athletic')
# (908, 'ati')
# (909, 'ation')
# (910, 'atlas')
# (911, 'atluri')
# (912, 'atmosphere')
# (913, 'atn')
# (914, 'atopic')
# (915, 'atorvastatin')
# (916, 'atpase')
# (917, 'atpbinding')
# (918, 'atresia')
# (919, 'atrial')
# (920, 'atrioven')
# (921, 'atrioventricu')
# (922, 'atrioventricular')
# (923, 'atrium')
# (924, 'atroblastomalike')
# (925, 'atrophic')
# (926, 'atrophy')
# (927, 'atrt')
# (928, 'att')
# (929, 'attached')
# (930, 'attaching')
# (931, 'attachment')
# (932, 'attack')
# (933, 'attainable')
# (934, 'attained')
# (935, 'attaining')
# (936, 'attempt')
# (937, 'attempted')
# (938, 'attend')
# (939, 'attended')
# (940, 'attention')
# (941, 'attentional')
# (942, 'attentive')
# (943, 'attenuate')
# (944, 'attenuated')
# (945, 'attenuates')
# (946, 'attenuation')
# (947, 'attenuationimaging')
# (948, 'attracted')
# (949, 'attractor')
# (950, 'attracts')
# (951, 'attributable')
# (952, 'attributed')
# (953, 'attribution')
# (954, 'attributionnon')
# (955, 'attributionnoncommercialnoderivatives')
# (956, 'ature')
# (957, 'atypi')
# (958, 'atypia')
# (959, 'atypical')
# (960, 'auc')
# (961, 'audiovisual')
# (962, 'augmented')
# (963, 'august')
# (964, 'auscultation')
# (965, 'australia')
# (966, 'australian')
# (967, 'austria')
# (968, 'author')
# (969, 'authorization')
# (970, 'authorship')
# (971, 'autism')
# (972, 'autistic')
# (973, 'auto')
# (974, 'autoantibody')
# (975, 'autoantibodymediated')
# (976, 'autoantibodyproducing')
# (977, 'autofilter')
# (978, 'autoflu')
# (979, 'autofluo')
# (980, 'autofluores')
# (981, 'autofluorescence')
# (982, 'autofluorescencelipofuscin')
# (983, 'autofluorescent')
# (984, 'autogenous')
# (985, 'autoimmune')
# (986, 'autoimmunerelated')
# (987, 'autoimmunity')
# (988, 'autologous')
# (989, 'automatic')
# (990, 'autonomic')
# (991, 'autonomous')
# (992, 'autophagylysosomal')
# (993, 'autopsied')
# (994, 'autopsy')
# (995, 'autoreactive')
# (996, 'autosomal')
# (997, 'autosomalrecessive')
# (998, 'auxiliary')
# (999, 'auxological')
# (1000, 'avagacestat')
# (1001, 'availability')
# (1002, 'available')
# (1003, 'avalglucosidase')
# (1004, 'avdc')
# (1005, 'average')
# (1006, 'averaging')
# (1007, 'aversa')
# (1008, 'avicenna')
# (1009, 'avid')
# (1010, 'avm')
# (1011, 'avmarteriovenous')
# (1012, 'avms')
# (1013, 'avoid')
# (1014, 'avoidance')
# (1015, 'avoided')
# (1016, 'avoiding')
# (1017, 'avp')
# (1018, 'awaiting')
# (1019, 'awaits')
# (1020, 'awake')
# (1021, 'awakened')
# (1022, 'awakening')
# (1023, 'award')
# (1024, 'aware')
# (1025, 'awareness')
# (1026, 'awave')
# (1027, 'away')
# (1028, 'awh')
# (1029, 'awoke')
# (1030, 'ax')
# (1031, 'axial')
# (1032, 'axilla')
# (1033, 'axillary')
# (1034, 'axis')
# (1035, 'axonal')
# (1036, 'ayano')
# (1037, 'azathioprine')
# (1038, 'azelastine')
# (1039, 'azithromycin')
# (1040, 'azole')
# (1041, 'azoles')
# (1042, 'azure')
# (1043, 'ba')
# (1044, 'babinski')
# (1045, 'bac')
# (1046, 'bacillus')
# (1047, 'back')
# (1048, 'background')
# (1049, 'backward')
# (1050, 'backwards')
# (1051, 'baclofen')
# (1052, 'bacteria')
# (1053, 'bacterial')
# (1054, 'bacterium')
# (1055, 'bacteriuria')
# (1056, 'bactrim')
# (1057, 'bad')
# (1058, 'baff')
# (1059, 'bagh')
# (1060, 'bai')
# (1061, 'balance')
# (1062, 'balanced')
# (1063, 'balbc')
# (1064, 'balf')
# (1065, 'balike')
# (1066, 'balint')
# (1067, 'balllbl')
# (1068, 'balllblblymphoblastic')
# (1069, 'ballman')
# (1070, 'balloon')
# (1071, 'balloonassisted')
# (1072, 'band')
# (1073, 'bandpass')
# (1074, 'bangaari')
# (1075, 'banjade')
# (1076, 'bank')
# (1077, 'banner')
# (1078, 'bao')
# (1079, 'bar')
# (1080, 'bardetbiedl')
# (1081, 'bare')
# (1082, 'bared')
# (1083, 'barometer')
# (1084, 'barrier')
# (1085, 'barry')
# (1086, 'barré')
# (1087, 'barthel')
# (1088, 'bartter')
# (1089, 'basaidarapur')
# (1090, 'basal')
# (1091, 'basally')
# (1092, 'base')
# (1093, 'based')
# (1094, 'basel')
# (1095, 'baseline')
# (1096, 'basic')
# (1097, 'basil')
# (1098, 'basis')
# (1099, 'basnet')
# (1100, 'basolateral')
# (1101, 'basolaterally')
# (1102, 'baspecific')
# (1103, 'bastakoti')
# (1104, 'batch')
# (1105, 'bated')
# (1106, 'bath')
# (1107, 'bathroom')
# (1108, 'batoclimab')
# (1109, 'batoclimabexhibited')
# (1110, 'batten')
# (1111, 'battery')
# (1112, 'baumannii')
# (1113, 'bax')
# (1114, 'baxter')
# (1115, 'bayat')
# (1116, 'bayer')
# (1117, 'bb')
# (1118, 'bbe')
# (1119, 'bbsome')
# (1120, 'bbþ')
# (1121, 'bca')
# (1122, 'bcell')
# (1123, 'bcellrelevant')
# (1124, 'bcl')
# (1125, 'bead')
# (1126, 'beadchip')
# (1127, 'beagle')
# (1128, 'bear')
# (1129, 'beat')
# (1130, 'beatsmin')
# (1131, 'beatsminute')
# (1132, 'became')
# (1133, 'become')
# (1134, 'becomes')
# (1135, 'becoming')
# (1136, 'bed')
# (1137, 'bedside')
# (1138, 'began')
# (1139, 'begin')
# (1140, 'beginning')
# (1141, 'behalf')
# (1142, 'behave')
# (1143, 'behavior')
# (1144, 'behavioral')
# (1145, 'behaviour')
# (1146, 'behavioural')
# (1147, 'beijing')
# (1148, 'beirut')
# (1149, 'believe')
# (1150, 'believed')
# (1151, 'belimumab')
# (1152, 'belong')
# (1153, 'belonged')
# (1154, 'belonging')
# (1155, 'belongs')
# (1156, 'ben')
# (1157, 'benbir')
# (1158, 'benedikt')
# (1159, 'beneficial')
# (1160, 'benefit')
# (1161, 'benefiting')
# (1162, 'benign')
# (1163, 'bent')
# (1164, 'benzodiazepine')
# (1165, 'ber')
# (1166, 'berg')
# (1167, 'bergmann')
# (1168, 'bernardi')
# (1169, 'bernstein')
# (1170, 'bertram')
# (1171, 'besides')
# (1172, 'beslow')
# (1173, 'best')
# (1174, 'bestperforming')
# (1175, 'beta')
# (1176, 'betagammasubunit')
# (1177, 'betahemolytic')
# (1178, 'betalactams')
# (1179, 'better')
# (1180, 'betterthis')
# (1181, 'betweengroup')
# (1182, 'bevinahalli')
# (1183, 'beyond')
# (1184, 'beyotime')
# (1185, 'bezza')
# (1186, 'bfigs')
# (1187, 'bial')
# (1188, 'biallelic')
# (1189, 'biannual')
# (1190, 'bias')
# (1191, 'bibek')
# (1192, 'bibliographic')
# (1193, 'bicanalicular')
# (1194, 'bicarbonate')
# (1195, 'bicinchoninic')
# (1196, 'bickerstaff')
# (1197, 'bid')
# (1198, 'bifrontal')
# (1199, 'bigeminy')
# (1200, 'biko')
# (1201, 'bilateral')
# (1202, 'bilaterally')
# (1203, 'bilateralmodified')
# (1204, 'bile')
# (1205, 'biliary')
# (1206, 'biliatresone')
# (1207, 'biliatresonetreated')
# (1208, 'bilious')
# (1209, 'bilirubin')
# (1210, 'bility')
# (1211, 'bind')
# (1212, 'binding')
# (1213, 'binging')
# (1214, 'binomial')
# (1215, 'bio')
# (1216, 'biobank')
# (1217, 'biobanks')
# (1218, 'biochemical')
# (1219, 'biochemistry')
# (1220, 'biocompatibility')
# (1221, 'bioconductor')
# (1222, 'biofilm')
# (1223, 'biogenesis')
# (1224, 'bioinformatic')
# (1225, 'biolegend')
# (1226, 'biologic')
# (1227, 'biological')
# (1228, 'biology')
# (1229, 'biomarker')
# (1230, 'biomarkers')
# (1231, 'biomedical')
# (1232, 'bionumerics')
# (1233, 'biopharm')
# (1234, 'bioproject')
# (1235, 'biopsied')
# (1236, 'biopsy')
# (1237, 'biopsyrelated')
# (1238, 'biopti')
# (1239, 'bioptigen')
# (1240, 'bioresources')
# (1241, 'bioscience')
# (1242, 'biosera')
# (1243, 'bioss')
# (1244, 'biosynthesis')
# (1245, 'biosystem')
# (1246, 'biosystems')
# (1247, 'biotech')
# (1248, 'biotechnology')
# (1249, 'biotic')
# (1250, 'biotinylated')
# (1251, 'biotium')
# (1252, 'bioworld')
# (1253, 'biphasic')
# (1254, 'biplane')
# (1255, 'bipn')
# (1256, 'bipolar')
# (1257, 'birtamode')
# (1258, 'birth')
# (1259, 'birthdates')
# (1260, 'bisbenzimide')
# (1261, 'bishala')
# (1262, 'bisretinoids')
# (1263, 'bistris')
# (1264, 'bit')
# (1265, 'bivariate')
# (1266, 'black')
# (1267, 'blackout')
# (1268, 'blad')
# (1269, 'bladder')
# (1270, 'bladderpreserving')
# (1271, 'bladdersparing')
# (1272, 'blair')
# (1273, 'blank')
# (1274, 'blardi')
# (1275, 'blast')
# (1276, 'ble')
# (1277, 'bleak')
# (1278, 'bled')
# (1279, 'bleeding')
# (1280, 'blending')
# (1281, 'blepharophimosis')
# (1282, 'blepharoptosis')
# (1283, 'blind')
# (1284, 'blinded')
# (1285, 'blinding')
# (1286, 'blindness')
# (1287, 'blister')
# (1288, 'blocher')
# (1289, 'block')
# (1290, 'blockade')
# (1291, 'blocked')
# (1292, 'blocker')
# (1293, 'blocking')
# (1294, 'blom')
# (1295, 'blood')
# (1296, 'bloodbrain')
# (1297, 'bloodmixed')
# (1298, 'bloodstained')
# (1299, 'bloodstream')
# (1300, 'bloody')
# (1301, 'blooming')
# (1302, 'blot')
# (1303, 'blotreference')
# (1304, 'blotting')
# (1305, 'blue')
# (1306, 'bluestained')
# (1307, 'blurred')
# (1308, 'bly')
# (1309, 'blymphoblastic')
# (1310, 'blymphocyte')
# (1311, 'blymphocytic')
# (1312, 'bmc')
# (1313, 'bmi')
# (1314, 'bmisds')
# (1315, 'bmp')
# (1316, 'board')
# (1317, 'boardcertified')
# (1318, 'body')
# (1319, 'boiling')
# (1320, 'bolster')
# (1321, 'bolus')
# (1322, 'bone')
# (1323, 'bonerelated')
# (1324, 'bonespecific')
# (1325, 'bonferroni')
# (1326, 'bonferronicorrected')
# (1327, 'bonferronis')
# (1328, 'bony')
# (1329, 'booth')
# (1330, 'bootstrapbased')
# (1331, 'bootstrapping')
# (1332, 'borasio')
# (1333, 'border')
# (1334, 'borderline')
# (1335, 'borgohain')
# (1336, 'born')
# (1337, 'borohydride')
# (1338, 'bosch')
# (1339, 'bostancı')
# (1340, 'botox')
# (1341, 'bottle')
# (1342, 'bottom')
# (1343, 'botulinum')
# (1344, 'bouattour')
# (1345, 'bought')
# (1346, 'bougie')
# (1347, 'bound')
# (1348, 'boundary')
# (1349, 'bourdeaut')
# (1350, 'boussignac')
# (1351, 'bovine')
# (1352, 'bowel')
# (1353, 'bowtie')
# (1354, 'box')
# (1355, 'boxed')
# (1356, 'boy')
# (1357, 'bozzo')
# (1358, 'bpcbenzylpenicillin')
# (1359, 'bplasma')
# (1360, 'bpm')
# (1361, 'bpreviously')
# (1362, 'bra')
# (1363, 'braak')
# (1364, 'brachial')
# (1365, 'brachioradialis')
# (1366, 'bradycardia')
# (1367, 'braf')
# (1368, 'brain')
# (1369, 'brainderived')
# (1370, 'brainenhanced')
# (1371, 'brainstem')
# (1372, 'bramycin')
# (1373, 'branch')
# (1374, 'branched')
# (1375, 'branchedchain')
# (1376, 'branching')
# (1377, 'brated')
# (1378, 'brazil')
# (1379, 'brazilian')
# (1380, 'brc')
# (1381, 'break')
# (1382, 'breakapart')
# (1383, 'breakdown')
# (1384, 'breakpoint')
# (1385, 'breakthrough')
# (1386, 'breast')
# (1387, 'breath')
# (1388, 'breathe')
# (1389, 'breathholding')
# (1390, 'breathing')
# (1391, 'breathlessness')
# (1392, 'bregs')
# (1393, 'brevis')
# (1394, 'bridement')
# (1395, 'bridge')
# (1396, 'bridging')
# (1397, 'brief')
# (1398, 'briefly')
# (1399, 'bril')
# (1400, 'bring')
# (1401, 'brisk')
# (1402, 'british')
# (1403, 'broad')
# (1404, 'broadens')
# (1405, 'broader')
# (1406, 'broadly')
# (1407, 'broadspectrum')
# (1408, 'brodsky')
# (1409, 'broken')
# (1410, 'bromide')
# (1411, 'bronchial')
# (1412, 'bronchiectasis')
# (1413, 'bronchitis')
# (1414, 'bronchoalveolar')
# (1415, 'bronchodilator')
# (1416, 'bronchoscope')
# (1417, 'bronchoscopic')
# (1418, 'bronchoscopy')
# (1419, 'bronchus')
# (1420, 'brophy')
# (1421, 'brother')
# (1422, 'brought')
# (1423, 'brown')
# (1424, 'bru')
# (1425, 'brucella')
# (1426, 'brucellaspecific')
# (1427, 'brucellosis')
# (1428, 'brucellosisinduced')
# (1429, 'brudzinskis')
# (1430, 'bruker')
# (1431, 'bsa')
# (1432, 'bstemosis')
# (1433, 'budden')
# (1434, 'buffer')
# (1435, 'buffered')
# (1436, 'buffersoluble')
# (1437, 'build')
# (1438, 'building')
# (1439, 'buildup')
# (1440, 'bulation')
# (1441, 'bulge')
# (1442, 'bulging')
# (1443, 'bulk')
# (1444, 'bultrasonic')
# (1445, 'bun')
# (1446, 'bundle')
# (1447, 'bur')
# (1448, 'burden')
# (1449, 'burlington')
# (1450, 'burning')
# (1451, 'burnout')
# (1452, 'bursitis')
# (1453, 'butler')
# (1454, 'bwave')
# (1455, 'bwould')
# (1456, 'bycase')
# (1457, 'bypass')
# (1458, 'bypassed')
# (1459, 'byrne')
# (1460, 'büscher')
# (1461, 'c1112_1113delinsct')
# (1462, 'c1162_1172del')
# (1463, 'c1269_1273del')
# (1464, 'ca')
# (1465, 'ca_ad')
# (1466, 'ca_nc')
# (1467, 'cacodylate')
# (1468, 'cadd')
# (1469, 'cades')
# (1470, 'cadg')
# (1471, 'caffarelli')
# (1472, 'cage')
# (1473, 'cal')
# (1474, 'calabresi')
# (1475, 'calcaneal')
# (1476, 'calcaneus')
# (1477, 'calcification')
# (1478, 'calcified')
# (1479, 'calcitoninogen')
# (1480, 'calcium')
# (1481, 'calcu')
# (1482, 'calculate')
# (1483, 'calculated')
# (1484, 'calculating')
# (1485, 'calculation')
# (1486, 'calderaro')
# (1487, 'cali')
# (1488, 'calibrated')
# (1489, 'calibration')
# (1490, 'california')
# (1491, 'call')
# (1492, 'called')
# (1493, 'calling')
# (1494, 'callosum')
# (1495, 'calm')
# (1496, 'calmetteguerin')
# (1497, 'calmly')
# (1498, 'cambridge')
# (1499, 'came')
# (1500, 'camel')
# (1501, 'camera')
# (1502, 'campal')
# (1503, 'campylobacter')
# (1504, 'canada')
# (1505, 'canadian')
# (1506, 'canal')
# (1507, 'canaliculus')
# (1508, 'canca')
# (1509, 'cancer')
# (1510, 'cancerrelated')
# (1511, 'candida')
# (1512, 'candidate')
# (1513, 'candidiasis')
# (1514, 'canine')
# (1515, 'canis')
# (1516, 'canisius')
# (1517, 'canon')
# (1518, 'cantly')
# (1519, 'cantonensis')
# (1520, 'capability')
# (1521, 'capacity')
# (1522, 'capchloramphenicol')
# (1523, 'capillary')
# (1524, 'capital')
# (1525, 'capsular')
# (1526, 'capsule')
# (1527, 'capture')
# (1528, 'captured')
# (1529, 'capturing')
# (1530, 'car')
# (1531, 'carbamazepine')
# (1532, 'carbidopa')
# (1533, 'carbidopalevodopa')
# (1534, 'carbocyanine')
# (1535, 'carbohydrate')
# (1536, 'carboplatin')
# (1537, 'carboxylate')
# (1538, 'carboxylic')
# (1539, 'carcinoma')
# (1540, 'carcinomatosis')
# (1541, 'cardia')
# (1542, 'cardiac')
# (1543, 'cardinal')
# (1544, 'cardiol')
# (1545, 'cardiology')
# (1546, 'cardiomyopathy')
# (1547, 'cardiorespiratory')
# (1548, 'cardiovascular')
# (1549, 'care')
# (1550, 'cared')
# (1551, 'careful')
# (1552, 'carefully')
# (1553, 'caregiver')
# (1554, 'carina')
# (1555, 'caring')
# (1556, 'carlsbad')
# (1557, 'carotid')
# (1558, 'carotidposterior')
# (1559, 'carpal')
# (1560, 'carri')
# (1561, 'carriage')
# (1562, 'carried')
# (1563, 'carrier')
# (1564, 'carry')
# (1565, 'carrying')
# (1566, 'carter')
# (1567, 'cartilage')
# (1568, 'cartilaginous')
# (1569, 'cascade')
# (1570, 'case')
# (1571, 'casecontrol')
# (1572, 'caspase')
# (1573, 'cassad')
# (1574, 'cassette')
# (1575, 'cast')
# (1576, 'castillo')
# (1577, 'castrated')
# (1578, 'cat')
# (1579, 'catalog')
# (1580, 'catalytic')
# (1581, 'catamenial')
# (1582, 'cated')
# (1583, 'catego')
# (1584, 'categorical')
# (1585, 'categorized')
# (1586, 'categorizing')
# (1587, 'category')
# (1588, 'catheter')
# (1589, 'catheterization')
# (1590, 'cating')
# (1591, 'cauda')
# (1592, 'caudal')
# (1593, 'causa')
# (1594, 'causal')
# (1595, 'causative')
# (1596, 'cause')
# (1597, 'caused')
# (1598, 'causespecific')
# (1599, 'causing')
# (1600, 'caution')
# (1601, 'cav')
# (1602, 'cava')
# (1603, 'cavernous')
# (1604, 'cavitation')
# (1605, 'cavitationyes')
# (1606, 'cavity')
# (1607, 'cba')
# (1608, 'cbacellbased')
# (1609, 'cbahipsc')
# (1610, 'cbahipscs')
# (1611, 'cbc')
# (1612, 'cbl')
# (1613, 'ccbyncnd')
# (1614, 'ccdr')
# (1615, 'cci')
# (1616, 'ccm')
# (1617, 'ccnu')
# (1618, 'cctcccttcacagcaaggta')
# (1619, 'cdc')
# (1620, 'cddpress')
# (1621, 'cdna')
# (1622, 'cease')
# (1623, 'ceased')
# (1624, 'cecilia')
# (1625, 'cefepime')
# (1626, 'cefixime')
# (1627, 'cefoperazone')
# (1628, 'cefotaxime')
# (1629, 'ceftriaxone')
# (1630, 'cefuroxime')
# (1631, 'ceived')
# (1632, 'celiac')
# (1633, 'cell')
# (1634, 'cella')
# (1635, 'cellbased')
# (1636, 'cellcell')
# (1637, 'cellday')
# (1638, 'cellderived')
# (1639, 'cellosis')
# (1640, 'cellrpe')
# (1641, 'cellsday')
# (1642, 'cellshpf')
# (1643, 'cellswell')
# (1644, 'cellu')
# (1645, 'cellular')
# (1646, 'cellularity')
# (1647, 'cellulitis')
# (1648, 'cement')
# (1649, 'cence')
# (1650, 'cencelipofuscin')
# (1651, 'cent')
# (1652, 'center')
# (1653, 'centered')
# (1654, 'centimeter')
# (1655, 'central')
# (1656, 'centralized')
# (1657, 'centre')
# (1658, 'centrifu')
# (1659, 'centrifugation')
# (1660, 'centrifuged')
# (1661, 'cephalosporin')
# (1662, 'ceps')
# (1663, 'ceptibility')
# (1664, 'ceptor')
# (1665, 'cer')
# (1666, 'cerad')
# (1667, 'cerebellar')
# (1668, 'cerebellum')
# (1669, 'cerebral')
# (1670, 'cerebrospinal')
# (1671, 'cerebrovascular')
# (1672, 'cerenia')
# (1673, 'ceroid')
# (1674, 'ceroidlipofuscinoses')
# (1675, 'certain')
# (1676, 'certainly')
# (1677, 'certainty')
# (1678, 'certified')
# (1679, 'ceruloplasmin')
# (1680, 'cervical')
# (1681, 'cervicalpredominant')
# (1682, 'cervicalthoracic')
# (1683, 'cervicothoracic')
# (1684, 'cesarean')
# (1685, 'cessation')
# (1686, 'cetiner')
# (1687, 'cfbl')
# (1688, 'cfigs')
# (1689, 'cga')
# (1690, 'cgh')
# (1691, 'cgifrs')
# (1692, 'chaban')
# (1693, 'chain')
# (1694, 'chair')
# (1695, 'chal')
# (1696, 'challenge')
# (1697, 'challenging')
# (1698, 'chamber')
# (1699, 'chance')
# (1700, 'chang')
# (1701, 'change')
# (1702, 'changed')
# (1703, 'changing')
# (1704, 'channel')
# (1705, 'chaochun')
# (1706, 'chaoyang')
# (1707, 'chapel')
# (1708, 'chapso')
# (1709, 'char')
# (1710, 'character')
# (1711, 'characteris')
# (1712, 'characterised')
# (1713, 'characteristic')
# (1714, 'characterization')
# (1715, 'characterize')
# (1716, 'characterized')
# (1717, 'characterizes')
# (1718, 'charcot')
# (1719, 'charcotlike')
# (1720, 'charged')
# (1721, 'charlson')
# (1722, 'chart')
# (1723, 'chas')
# (1724, 'chaussade')
# (1725, 'cheal')
# (1726, 'chear')
# (1727, 'chearjana')
# (1728, 'check')
# (1729, 'checked')
# (1730, 'checking')
# (1731, 'checklist')
# (1732, 'checkpoint')
# (1733, 'checkup')
# (1734, 'ched')
# (1735, 'cheek')
# (1736, 'chemical')
# (1737, 'chemiluminescence')
# (1738, 'chemokine')
# (1739, 'chemosensitive')
# (1740, 'chemosis')
# (1741, 'chemotherapeutic')
# (1742, 'chemotherapy')
# (1743, 'chen')
# (1744, 'chest')
# (1745, 'cheyenne')
# (1746, 'chi')
# (1747, 'chial')
# (1748, 'chiari')
# (1749, 'chiasm')
# (1750, 'chiba')
# (1751, 'chicago')
# (1752, 'chikai')
# (1753, 'chil')
# (1754, 'child')
# (1755, 'childbearing')
# (1756, 'childbirth')
# (1757, 'childcare')
# (1758, 'childhood')
# (1759, 'childhoodonset')
# (1760, 'childrens')
# (1761, 'chill')
# (1762, 'china')
# (1763, 'chinese')
# (1764, 'ching')
# (1765, 'chip')
# (1766, 'chisquare')
# (1767, 'chisquared')
# (1768, 'chloride')
# (1769, 'choice')
# (1770, 'cholangiocytes')
# (1771, 'cholangiopathy')
# (1772, 'cholangitis')
# (1773, 'cholecystitis')
# (1774, 'cholestasis')
# (1775, 'cholestatic')
# (1776, 'cholesterol')
# (1777, 'cholinesterase')
# (1778, 'chondrolysis')
# (1779, 'chong')
# (1780, 'chongbo')
# (1781, 'choose')
# (1782, 'choosing')
# (1783, 'chopping')
# (1784, 'choroidal')
# (1785, 'chose')
# (1786, 'chr')
# (1787, 'christian')
# (1788, 'christina')
# (1789, 'chro')
# (1790, 'chromatin')
# (1791, 'chromatography')
# (1792, 'chromo')
# (1793, 'chromosomal')
# (1794, 'chromosome')
# (1795, 'chronic')
# (1796, 'chronically')
# (1797, 'chunming')
# (1798, 'chunyuan')
# (1799, 'chunzhen')
# (1800, 'churgstrauss')
# (1801, 'cially')
# (1802, 'ciclosporin')
# (1803, 'cidioides')
# (1804, 'cidioidomycosis')
# (1805, 'cidp')
# (1806, 'cie')
# (1807, 'cieassociated')
# (1808, 'ciently')
# (1809, 'cierelated')
# (1810, 'cifically')
# (1811, 'cifrs')
# (1812, 'cigarette')
# (1813, 'ciliary')
# (1814, 'ciliarydependent')
# (1815, 'ciliopathies')
# (1816, 'ciliopathy')
# (1817, 'cilium')
# (1818, 'cinautofluorescence')
# (1819, 'cipa')
# (1820, 'cipaglucosidase')
# (1821, 'cipamig')
# (1822, 'cipamigcipaglucosidase')
# (1823, 'cipitating')
# (1824, 'ciprofloxacin')
# (1825, 'cir')
# (1826, 'circle')
# (1827, 'circuitry')
# (1828, 'circula')
# (1829, 'circular')
# (1830, 'circulating')
# (1831, 'circulation')
# (1832, 'circumference')
# (1833, 'circumscribed')
# (1834, 'circumstance')
# (1835, 'cirrhosis')
# (1836, 'cirrhotic')
# (1837, 'cisternography')
# (1838, 'citation')
# (1839, 'cited')
# (1840, 'citrate')
# (1841, 'citrullinated')
# (1842, 'city')
# (1843, 'cium')
# (1844, 'ckd')
# (1845, 'claeys')
# (1846, 'claim')
# (1847, 'clancy')
# (1848, 'clarify')
# (1849, 'clarissa')
# (1850, 'clarithromycin')
# (1851, 'clark')
# (1852, 'clarke')
# (1853, 'class')
# (1854, 'classed')
# (1855, 'classic')
# (1856, 'classical')
# (1857, 'classically')
# (1858, 'classification')
# (1859, 'classified')
# (1860, 'classifier')
# (1861, 'classify')
# (1862, 'claudia')
# (1863, 'claudication')
# (1864, 'clc')
# (1865, 'cldmclindamycin')
# (1866, 'clean')
# (1867, 'cleaned')
# (1868, 'clear')
# (1869, 'clearance')
# (1870, 'cleared')
# (1871, 'clearer')
# (1872, 'clearly')
# (1873, 'cleavage')
# (1874, 'cleaved')
# (1875, 'cleaves')
# (1876, 'cles')
# (1877, 'cleveland')
# (1878, 'client')
# (1879, 'climbing')
# (1880, 'clin')
# (1881, 'clindamycin')
# (1882, 'clini')
# (1883, 'clinic')
# (1884, 'clinical')
# (1885, 'clinically')
# (1886, 'clinicallyascertained')
# (1887, 'clinicaltrialsgov')
# (1888, 'clinician')
# (1889, 'clinicopathological')
# (1890, 'cln')
# (1891, 'clock')
# (1892, 'clonal')
# (1893, 'clonazepam')
# (1894, 'clone')
# (1895, 'cloner')
# (1896, 'clonorchis')
# (1897, 'close')
# (1898, 'closed')
# (1899, 'closely')
# (1900, 'closer')
# (1901, 'closure')
# (1902, 'clozapine')
# (1903, 'clubbing')
# (1904, 'clude')
# (1905, 'cluding')
# (1906, 'clue')
# (1907, 'clumsiness')
# (1908, 'cluster')
# (1909, 'clustering')
# (1910, 'cm')
# (1911, 'cnb')
# (1912, 'cns')
# (1913, 'cnscentral')
# (1914, 'cnsrare')
# (1915, 'cnv')
# (1916, 'cnvcgh')
# (1917, 'coagulaion')
# (1918, 'coagulation')
# (1919, 'coagulative')
# (1920, 'coanalyzed')
# (1921, 'coarse')
# (1922, 'coaxially')
# (1923, 'cobicistat')
# (1924, 'coc')
# (1925, 'coccid')
# (1926, 'coccidioidal')
# (1927, 'coccidioides')
# (1928, 'coccidioidomy')
# (1929, 'coccidioidomycosis')
# (1930, 'coccidiomyco')
# (1931, 'coccidiomycosis')
# (1932, 'cochrane')
# (1933, 'cocker')
# (1934, 'cocktail')
# (1935, 'coco')
# (1936, 'coconut')
# (1937, 'coculture')
# (1938, 'code')
# (1939, 'coded')
# (1940, 'coding')
# (1941, 'coe')
# (1942, 'coecenter')
# (1943, 'coefficient')
# (1944, 'coes')
# (1945, 'coexist')
# (1946, 'coexistence')
# (1947, 'coexisting')
# (1948, 'coffee')
# (1949, 'cog')
# (1950, 'cogni')
# (1951, 'cognition')
# (1952, 'cognitionrelated')
# (1953, 'cognitive')
# (1954, 'cognitively')
# (1955, 'cohen')
# (1956, 'cohens')
# (1957, 'coherence')
# (1958, 'cohort')
# (1959, 'coil')
# (1960, 'coimmunoprecipitation')
# (1961, 'coimmunostaining')
# (1962, 'coincided')
# (1963, 'coincidence')
# (1964, 'coincides')
# (1965, 'coinfection')
# (1966, 'coinfections')
# (1967, 'coinfectiontraining')
# (1968, 'cointeraction')
# (1969, 'coip')
# (1970, 'col')
# (1971, 'coli')
# (1972, 'colitis')
# (1973, 'collaboration')
# (1974, 'collagen')
# (1975, 'collagenase')
# (1976, 'collagenous')
# (1977, 'collapse')
# (1978, 'collar')
# (1979, 'collateral')
# (1980, 'colleague')
# (1981, 'collect')
# (1982, 'collected')
# (1983, 'collecting')
# (1984, 'collection')
# (1985, 'collectively')
# (1986, 'college')
# (1987, 'coloc')
# (1988, 'colocalization')
# (1989, 'colocalizations')
# (1990, 'colocalized')
# (1991, 'colon')
# (1992, 'colonic')
# (1993, 'colonization')
# (1994, 'colonizes')
# (1995, 'colonoscopic')
# (1996, 'colonoscopy')
# (1997, 'colony')
# (1998, 'columbia')
# (1999, 'column')
# (2000, 'com')
# (2001, 'coma')
# (2002, 'comatose')
# (2003, 'comb')
# (2004, 'combat')
# (2005, 'combination')
# (2006, 'combinatorial')
# (2007, 'combine')
# (2008, 'combined')
# (2009, 'combinedmg')
# (2010, 'combing')
# (2011, 'combining')
# (2012, 'come')
# (2013, 'coming')
# (2014, 'command')
# (2015, 'commences')
# (2016, 'comment')
# (2017, 'commented')
# (2018, 'commer')
# (2019, 'commercial')
# (2020, 'commercially')
# (2021, 'commercialno')
# (2022, 'commit')
# (2023, 'commitment')
# (2024, 'committee')
# (2025, 'common')
# (2026, 'commonly')
# (2027, 'commonplace')
# (2028, 'commun')
# (2029, 'communicate')
# (2030, 'communicating')
# (2031, 'communication')
# (2032, 'community')
# (2033, 'communityacquired')
# (2034, 'comorbid')
# (2035, 'comorbidities')
# (2036, 'comorbidity')
# (2037, 'compact')
# (2038, 'company')
# (2039, 'comparable')
# (2040, 'comparably')
# (2041, 'comparation')
# (2042, 'comparative')
# (2043, 'comparatively')
# (2044, 'compare')
# (2045, 'compared')
# (2046, 'comparing')
# (2047, 'comparison')
# (2048, 'comparisonsbbs')
# (2049, 'compartment')
# (2050, 'compat')
# (2051, 'compati')
# (2052, 'compatible')
# (2053, 'compensation')
# (2054, 'compensatory')
# (2055, 'competing')
# (2056, 'competitively')
# (2057, 'compiled')
# (2058, 'complain')
# (2059, 'complaining')
# (2060, 'complaint')
# (2061, 'complement')
# (2062, 'complementary')
# (2063, 'complete')
# (2064, 'completed')
# (2065, 'completely')
# (2066, 'completer')
# (2067, 'completers')
# (2068, 'completing')
# (2069, 'completion')
# (2070, 'complex')
# (2071, 'complexity')
# (2072, 'compliance')
# (2073, 'complicate')
# (2074, 'complicated')
# (2075, 'complicates')
# (2076, 'complicating')
# (2077, 'complication')
# (2078, 'comply')
# (2079, 'compo')
# (2080, 'component')
# (2081, 'composed')
# (2082, 'composition')
# (2083, 'compound')
# (2084, 'comprehended')
# (2085, 'comprehension')
# (2086, 'comprehensive')
# (2087, 'comprehensively')
# (2088, 'compress')
# (2089, 'compression')
# (2090, 'compressive')
# (2091, 'comprised')
# (2092, 'comprises')
# (2093, 'comprising')
# (2094, 'compromise')
# (2095, 'compromised')
# (2096, 'computational')
# (2097, 'compute')
# (2098, 'computed')
# (2099, 'computer')
# (2100, 'computing')
# (2101, 'con')
# (2102, 'conazole')
# (2103, 'concave')
# (2104, 'concealment')
# (2105, 'conceived')
# (2106, 'concen')
# (2107, 'concentra')
# (2108, 'concentrate')
# (2109, 'concentrated')
# (2110, 'concentration')
# (2111, 'concept')
# (2112, 'conception')
# (2113, 'conceptualization')
# (2114, 'concern')
# (2115, 'concerned')
# (2116, 'concerning')
# (2117, 'conclude')
# (2118, 'concluded')
# (2119, 'conclusion')
# (2120, 'concomitant')
# (2121, 'concomitantly')
# (2122, 'concurrent')
# (2123, 'concurrently')
# (2124, 'condition')
# (2125, 'conditional')
# (2126, 'conditioned')
# (2127, 'conditionfig')
# (2128, 'conditioning')
# (2129, 'conducive')
# (2130, 'conduct')
# (2131, 'conducted')
# (2132, 'conducting')
# (2133, 'conduction')
# (2134, 'condylar')
# (2135, 'condyle')
# (2136, 'cone')
# (2137, 'conference')
# (2138, 'conferring')
# (2139, 'confficting')
# (2140, 'confidence')
# (2141, 'confident')
# (2142, 'confidential')
# (2143, 'configuration')
# (2144, 'confined')
# (2145, 'confirm')
# (2146, 'confirmaprotective')
# (2147, 'confirmation')
# (2148, 'confirmatory')
# (2149, 'confirmed')
# (2150, 'confirming')
# (2151, 'confirms')
# (2152, 'conflict')
# (2153, 'conflicting')
# (2154, 'confluence')
# (2155, 'confluency')
# (2156, 'confluent')
# (2157, 'confo')
# (2158, 'confocal')
# (2159, 'conformed')
# (2160, 'confounding')
# (2161, 'confuse')
# (2162, 'confused')
# (2163, 'confusion')
# (2164, 'congeni')
# (2165, 'congenital')
# (2166, 'congenitally')
# (2167, 'congested')
# (2168, 'conjugately')
# (2169, 'conjunction')
# (2170, 'conjunctiva')
# (2171, 'conjunctival')
# (2172, 'conly')
# (2173, 'connected')
# (2174, 'connection')
# (2175, 'connective')
# (2176, 'consanguineous')
# (2177, 'conscious')
# (2178, 'consciousness')
# (2179, 'conse')
# (2180, 'consecutive')
# (2181, 'consensus')
# (2182, 'consent')
# (2183, 'consequence')
# (2184, 'consequent')
# (2185, 'consequentially')
# (2186, 'consequently')
# (2187, 'conservative')
# (2188, 'conservatively')
# (2189, 'conservativelysix')
# (2190, 'consid')
# (2191, 'consider')
# (2192, 'considerable')
# (2193, 'considerably')
# (2194, 'consideration')
# (2195, 'considered')
# (2196, 'considering')
# (2197, 'consisted')
# (2198, 'consistency')
# (2199, 'consistent')
# (2200, 'consistently')
# (2201, 'consisting')
# (2202, 'consists')
# (2203, 'consolidate')
# (2204, 'consolidation')
# (2205, 'consortias')
# (2206, 'consortium')
# (2207, 'constant')
# (2208, 'constantly')
# (2209, 'constantvoltage')
# (2210, 'constipation')
# (2211, 'constituent')
# (2212, 'constitute')
# (2213, 'constitutes')
# (2214, 'constituting')
# (2215, 'constraint')
# (2216, 'construct')
# (2217, 'constructed')
# (2218, 'construed')
# (2219, 'consultation')
# (2220, 'consulting')
# (2221, 'consume')
# (2222, 'consuming')
# (2223, 'consumption')
# (2224, 'contact')
# (2225, 'contacted')
# (2226, 'contacting')
# (2227, 'contained')
# (2228, 'containing')
# (2229, 'contaminated')
# (2230, 'contamination')
# (2231, 'contemporary')
# (2232, 'content')
# (2233, 'contentious')
# (2234, 'context')
# (2235, 'conti')
# (2236, 'contiguous')
# (2237, 'contin')
# (2238, 'continue')
# (2239, 'continued')
# (2240, 'continues')
# (2241, 'continuing')
# (2242, 'continuity')
# (2243, 'continuous')
# (2244, 'continuously')
# (2245, 'contour')
# (2246, 'contraception')
# (2247, 'contracture')
# (2248, 'contradiction')
# (2249, 'contraindicated')
# (2250, 'contralateral')
# (2251, 'contrary')
# (2252, 'contrast')
# (2253, 'contrasted')
# (2254, 'contrastenhanced')
# (2255, 'contrastinduced')
# (2256, 'contrasting')
# (2257, 'contribute')
# (2258, 'contributed')
# (2259, 'contributes')
# ...
# (4387, 47, 2, 0.012012392202730425, '[2134, 2411]')
# (849, 47, 3, 0.02011551965289789, '[2143, 2599, 3467]')
# (2036, 47, 1, 0.005014650015972395, '[2145]')
# (2012, 47, 1, 0.004023103930579578, '[2157]')
# (8813, 47, 2, 0.00665717134000626, '[2172, 3042]')
# (3602, 47, 2, 0.006063115690373523, '[2175, 2597]')
# (5, 47, 2, 0.009390886947417727, '[2179, 2614]')
# (4205, 47, 1, 0.006006196101365212, '[2180]')
# (6676, 47, 2, 0.035477061906245916, '[2182, 2200]')
# (6582, 47, 2, 0.00998575701000939, '[2183, 2201]')
# (6597, 47, 1, 0.006006196101365212, '[2186]')
# (6818, 47, 1, 0.006006196101365212, '[2187]')
# (197, 47, 4, 0.012126231380747046, '[2188, 2243, 3402, 3495]')
# (3845, 47, 1, 0.005426178823673557, '[2191]')
# (6139, 47, 2, 0.009390886947417727, '[2194, 2763]')
# (4375, 47, 3, 0.018018588304095636, '[2195, 2265, 2267]')
# (3662, 47, 1, 0.005426178823673557, '[2197]')
# (10099, 47, 2, 0.005571452579541199, '[2203, 2414]')
# (4388, 47, 1, 0.006006196101365212, '[2205]')
# (5262, 47, 3, 0.011563846381767256, '[2208, 2862, 3511]')
# (10843, 47, 1, 0.005426178823673557, '[2214]')
# (462, 47, 5, 0.02011551965289789, '[2216, 2917, 3064, 3104, 3235]')
# (3573, 47, 1, 0.006006196101365212, '[2217]')
# (8683, 47, 1, 0.003567556307614081, '[2218]')
# (8389, 47, 1, 0.0027857262897705995, '[2221]')
# (3158, 47, 2, 0.007709230921178169, '[2222, 2579]')
# (9960, 47, 1, 0.004214120403483556, '[2223]')
# (1386, 47, 1, 0.005014650015972395, '[2224]')
# (11534, 47, 1, 0.005014650015972395, '[2228]')
# (1946, 47, 1, 0.0046954434737088635, '[2230]')
# (85, 47, 2, 0.005571452579541199, '[2234, 2335]')
# (5434, 47, 1, 0.0046954434737088635, '[2236]')
# (8246, 47, 3, 0.006693084698093764, '[2239, 2409, 3370]')
# (3486, 47, 2, 0.010852357647347113, '[2242, 3494]')
# (6302, 47, 1, 0.0044346327382807395, '[2245]')
# (522, 47, 1, 0.006006196101365212, '[2246]')
# (469, 47, 1, 0.005014650015972395, '[2247]')
# (8896, 47, 1, 0.005426178823673557, '[2248]')
# (1703, 47, 1, 0.0046954434737088635, '[2251]')
# (7472, 47, 2, 0.01002930003194479, '[2252, 2717]')
# (2499, 47, 1, 0.006006196101365212, '[2253]')
# (463, 47, 1, 0.0046954434737088635, '[2255]')
# (9941, 47, 1, 0.008428240806967111, '[2257]')
# (6010, 47, 1, 0.006006196101365212, '[2264]')
# (11461, 47, 2, 0.003906576643869675, '[2266, 3285]')
# (7949, 47, 1, 0.006006196101365212, '[2273]')
# (8146, 47, 1, 0.006006196101365212, '[2286]')
# (2383, 47, 4, 0.02402478440546085, '[2288, 2473, 2493, 2497]')
# (10885, 47, 1, 0.006006196101365212, '[2300]')
# (4312, 47, 1, 0.07982338928905332, '[2301]')
# (6541, 47, 2, 0.009390886947417727, '[2302, 2488]')
# (11, 47, 1, 0.004214120403483556, '[2304]')
# (5717, 47, 1, 0.006006196101365212, '[2305]')
# (1336, 47, 1, 0.0046954434737088635, '[2316]')
# (11128, 47, 3, 0.006120035279381835, '[2318, 2359, 2627]')
# (2561, 47, 3, 0.014815589553264188, '[2322, 2363, 2451]')
# (5206, 47, 1, 0.00271235130292323, '[2330]')
# (644, 47, 1, 0.005426178823673557, '[2336]')
# (6032, 47, 1, 0.00332858567000313, '[2338]')
# (3119, 47, 1, 0.002863069375196268, '[2339]')
# (4273, 47, 1, 0.006006196101365212, '[2342]')
# (5263, 47, 1, 0.005014650015972395, '[2344]')
# (6237, 47, 1, 0.005014650015972395, '[2349]')
# (5936, 47, 1, 0.005014650015972395, '[2350]')
# (5698, 47, 2, 0.012012392202730425, '[2351, 2563]')
# (3641, 47, 1, 0.0038546154605890847, '[2352]')
# (6851, 47, 1, 0.0046954434737088635, '[2360]')
# (4752, 47, 1, 0.0017941802043777825, '[2361]')
# (5305, 47, 1, 0.0038546154605890847, '[2364]')
# (3443, 47, 1, 0.005014650015972395, '[2368]')
# (3711, 47, 2, 0.005726138750392536, '[2371, 2574]')
# (10464, 47, 2, 0.012012392202730425, '[2373, 2386]')
# (9986, 47, 1, 0.006006196101365212, '[2374]')
# (10703, 47, 2, 0.010852357647347113, '[2375, 2406]')
# (4261, 47, 1, 0.0046954434737088635, '[2381]')
# (8436, 47, 1, 0.006006196101365212, '[2387]')
# (8161, 47, 1, 0.005014650015972395, '[2396]')
# (5806, 47, 1, 0.0025124220371978245, '[2397]')
# (8580, 47, 1, 0.004023103930579578, '[2401]')
# (218, 47, 1, 0.002642557040399083, '[2402]')
# (260, 47, 1, 0.005014650015972395, '[2412]')
# (15, 47, 1, 0.004214120403483556, '[2427]')
# (1169, 47, 1, 0.006006196101365212, '[2428]')
# (6386, 47, 1, 0.0038546154605890847, '[2438]')
# (6114, 47, 1, 0.006006196101365212, '[2440]')
# (1462, 47, 1, 0.006006196101365212, '[2448]')
# (5982, 47, 1, 0.004214120403483556, '[2449]')
# (9541, 47, 1, 0.006256284686779159, '[2453]')
# (4131, 47, 1, 0.004023103930579578, '[2454]')
# (2936, 47, 1, 0.0038546154605890847, '[2464]')
# (4991, 47, 1, 0.004023103930579578, '[2472]')
# (10445, 47, 1, 0.00332858567000313, '[2474]')
# (9226, 47, 1, 0.005426178823673557, '[2480]')
# (9432, 47, 1, 0.00332858567000313, '[2481]')
# (5328, 47, 1, 0.004214120403483556, '[2489]')
# (3652, 47, 3, 0.009371640331873175, '[2503, 2681, 3454]')
# (5402, 47, 1, 0.0044346327382807395, '[2530]')
# (2191, 47, 1, 0.003703897388316047, '[2533]')
# (2978, 47, 1, 0.005426178823673557, '[2535]')
# (11413, 47, 1, 0.004023103930579578, '[2537]')
# (10794, 47, 1, 0.004214120403483556, '[2538]')
# (8707, 47, 1, 0.00332858567000313, '[2539]')
# (9010, 47, 1, 0.0017208052175304136, '[2549]')
# (1005, 47, 1, 0.003567556307614081, '[2550]')
# (8640, 47, 1, 0.004214120403483556, '[2567]')
# (8191, 47, 1, 0.006006196101365212, '[2569]')
# (2045, 47, 1, 0.0025124220371978245, '[2570]')
# (11418, 47, 3, 0.00998575701000939, '[2573, 3134, 3259]')
# (7253, 47, 1, 0.003703897388316047, '[2578]')
# (2780, 47, 1, 0.0046954434737088635, '[2583]')
# (2896, 47, 1, 0.0046954434737088635, '[2588]')
# (229, 47, 2, 0.010852357647347113, '[2592, 3536]')
# (2029, 47, 1, 0.006006196101365212, '[2593]')
# (9791, 47, 2, 0.006445148636181477, '[2598, 3521]')
# (4521, 47, 1, 0.005426178823673557, '[2602]')
# (603, 47, 1, 0.005014650015972395, '[2604]')
# (11372, 47, 1, 0.006006196101365212, '[2605]')
# (8716, 47, 2, 0.009390886947417727, '[2610, 3459]')
# (5983, 47, 1, 0.006006196101365212, '[2613]')
# (6144, 47, 2, 0.007407794776632094, '[2622, 3420]')
# (4798, 47, 3, 0.015043950047917186, '[2628, 2667, 3231]')
# (2246, 47, 1, 0.005426178823673557, '[2629]')
# (5839, 47, 1, 0.0025760102222212636, '[2632]')
# (10231, 47, 1, 0.009704103665568902, '[2634]')
# (3138, 47, 2, 0.012012392202730425, '[2635, 2672]')
# (1047, 47, 1, 0.00332858567000313, '[2640]')
# (7527, 47, 1, 0.0024515405674951063, '[2641]')
# (9000, 47, 1, 0.0038546154605890847, '[2646]')
# (6351, 47, 1, 0.006006196101365212, '[2657]')
# (5785, 47, 1, 0.0025124220371978245, '[2659]')
# (3218, 47, 1, 0.00332858567000313, '[2666]')
# (10783, 47, 1, 0.0016173506109281503, '[2668]')
# (3328, 47, 1, 0.005014650015972395, '[2673]')
# (5753, 47, 1, 0.006006196101365212, '[2674]')
# (5177, 47, 2, 0.005726138750392536, '[2682, 2983]')
# (1581, 47, 1, 0.006006196101365212, '[2683]')
# (2498, 47, 1, 0.007135112615228162, '[2686]')
# (134, 47, 1, 0.004214120403483556, '[2695]')
# (4514, 47, 1, 0.003703897388316047, '[2696]')
# (8174, 47, 1, 0.0032225743180907384, '[2701]')
# (7295, 47, 1, 0.006006196101365212, '[2702]')
# (492, 47, 2, 0.012012392202730425, '[2704, 2725]')
# (8837, 47, 1, 0.005426178823673557, '[2705]')
# (3451, 47, 1, 0.00332858567000313, '[2706]')
# (10090, 47, 1, 0.0044346327382807395, '[2709]')
# (8190, 47, 1, 0.004023103930579578, '[2716]')
# (7996, 47, 4, 0.02402478440546085, '[2719, 2730, 2742, 2756]')
# (3419, 47, 2, 0.008428240806967111, '[2726, 3152]')
# (5951, 47, 1, 0.003567556307614081, '[2728]')
# (4088, 47, 1, 0.006006196101365212, '[2736]')
# (6378, 47, 1, 0.006006196101365212, '[2737]')
# (9057, 47, 1, 0.005014650015972395, '[2738]')
# (3587, 47, 1, 0.0032225743180907384, '[2744]')
# (6013, 47, 1, 0.003567556307614081, '[2745]')
# (6028, 47, 1, 0.002863069375196268, '[2746]')
# (791, 47, 1, 0.004214120403483556, '[2747]')
# (7010, 47, 1, 0.0030315578451867616, '[2750]')
# (3718, 47, 2, 0.008428240806967111, '[2755, 3215]')
# (3001, 47, 1, 0.0032225743180907384, '[2761]')
# (6238, 47, 2, 0.009390886947417727, '[2764, 2994]')
# (9897, 47, 2, 0.005571452579541199, '[2766, 2996]')
# (10240, 47, 1, 0.005426178823673557, '[2773]')
# (3663, 47, 1, 0.006006196101365212, '[2774]')
# (5296, 47, 1, 0.0046954434737088635, '[2775]')
# (4741, 47, 1, 0.003567556307614081, '[2776]')
# (7617, 47, 3, 0.018018588304095636, '[2782, 2799, 2802]')
# (1669, 47, 1, 0.0032225743180907384, '[2784]')
# (2333, 47, 2, 0.009390886947417727, '[2785, 2813]')
# (9498, 47, 1, 0.0044346327382807395, '[2786]')
# (4952, 47, 2, 0.012012392202730425, '[2789, 2819]')
# (6982, 47, 1, 0.005014650015972395, '[2792]')
# (5352, 47, 1, 0.004023103930579578, '[2797]')
# (2610, 47, 2, 0.005571452579541199, '[2798, 2886]')
# (4176, 47, 2, 0.012012392202730425, '[2800, 2805]')
# (5040, 47, 1, 0.006006196101365212, '[2810]')
# (2334, 47, 1, 0.0046954434737088635, '[2811]')
# (4055, 47, 3, 0.00998575701000939, '[2812, 3188, 3208]')
# (2628, 47, 1, 0.005426178823673557, '[2814]')
# (7853, 47, 1, 0.004214120403483556, '[2816]')
# (4857, 47, 1, 0.006006196101365212, '[2824]')
# (7974, 47, 1, 0.0046954434737088635, '[2825]')
# (9917, 47, 1, 0.003703897388316047, '[2826]')
# (5505, 47, 1, 0.005426178823673557, '[2828]')
# (4251, 47, 1, 0.004214120403483556, '[2830]')
# (5720, 47, 2, 0.009390886947417727, '[2831, 2846]')
# (8294, 47, 1, 0.006006196101365212, '[2833]')
# (5477, 47, 1, 0.003703897388316047, '[2837]')
# (2650, 47, 2, 0.012012392202730425, '[2844, 2855]')
# (4800, 47, 1, 0.006006196101365212, '[2851]')
# (862, 47, 1, 0.0046954434737088635, '[2863]')
# (3772, 47, 1, 0.0038546154605890847, '[2873]')
# (2282, 47, 1, 0.006006196101365212, '[2876]')
# (9456, 47, 1, 0.002642557040399083, '[2887]')
# (2110, 47, 1, 0.01609241572231831, '[2889]')
# (6517, 47, 1, 0.0044346327382807395, '[2892]')
# (10854, 47, 5, 0.02347721736854432, '[2894, 2933, 2949, 2979, 2986]')
# (4953, 47, 2, 0.012012392202730425, '[2900, 3020]')
# (10781, 47, 1, 0.0021808301481265843, '[2904]')
# (2119, 47, 2, 0.004852051832784451, '[2907, 3577]')
# (8251, 47, 2, 0.004170856457852772, '[2915, 3422]')
# (4945, 47, 1, 0.006006196101365212, '[2918]')
# (1034, 47, 2, 0.010852357647347113, '[2919, 3268]')
# (301, 47, 1, 0.006006196101365212, '[2930]')
# (7934, 47, 2, 0.008428240806967111, '[2931, 3275]')
# (10855, 47, 1, 0.006006196101365212, '[2934]')
# (9048, 47, 1, 0.005014650015972395, '[2935]')
# (11228, 47, 1, 0.0044346327382807395, '[2954]')
# (8641, 47, 1, 0.0046954434737088635, '[2958]')
# (9903, 47, 1, 0.0034430866528879227, '[2959]')
# (9580, 47, 1, 0.0029448344073276546, '[2960]')
# (8752, 47, 2, 0.007709230921178169, '[2981, 3278]')
# (936, 47, 1, 0.003703897388316047, '[2982]')
# (6137, 47, 1, 0.004214120403483556, '[2984]')
# (191, 47, 2, 0.008428240806967111, '[2985, 3133]')
# (5897, 47, 1, 0.01871523289803451, '[2990]')
# (10521, 47, 1, 0.003567556307614081, '[2991]')
# (9868, 47, 1, 0.005014650015972395, '[2993]')
# (5341, 47, 1, 0.0044346327382807395, '[2997]')
# (1002, 47, 2, 0.005285114080798166, '[2999, 3507]')
# (11007, 47, 2, 0.008869265476561479, '[3000, 3078]')
# (6607, 47, 1, 0.0034430866528879227, '[3001]')
# (2174, 47, 1, 0.005014650015972395, '[3002]')
# (764, 47, 1, 0.00271235130292323, '[3013]')
# (8598, 47, 1, 0.0031238801106243915, '[3016]')
# (985, 47, 1, 0.003567556307614081, '[3017]')
# (10549, 47, 1, 0.006006196101365212, '[3018]')
# (4914, 47, 1, 0.006006196101365212, '[3021]')
# (1868, 47, 1, 0.0031238801106243915, '[3026]')
# (1143, 47, 1, 0.0044346327382807395, '[3029]')
# (10739, 47, 1, 0.006006196101365212, '[3031]')
# (2843, 47, 1, 0.0044346327382807395, '[3033]')
# (8688, 47, 1, 0.006006196101365212, '[3046]')
# (7329, 47, 1, 0.005014650015972395, '[3049]')
# (10146, 47, 1, 0.0031238801106243915, '[3059]')
# (3483, 47, 1, 0.005426178823673557, '[3065]')
# (1323, 47, 1, 0.006006196101365212, '[3067]')
# (9574, 47, 1, 0.004214120403483556, '[3069]')
# (8600, 47, 1, 0.006006196101365212, '[3072]')
# (1179, 47, 2, 0.006247760221248783, '[3077, 3634]')
# (8821, 47, 1, 0.0034430866528879227, '[3085]')
# (9652, 47, 1, 0.0038546154605890847, '[3090]')
# (10089, 47, 1, 0.005014650015972395, '[3103]')
# (2695, 47, 6, 0.021405337845684484, '[3112, 3228, 3294, 3309, 3330, 3337]')
# (4087, 47, 2, 0.012642361210450665, '[3114, 3393]')
# (8619, 47, 2, 0.0043616602962531685, '[3115, 3186]')
# (5617, 47, 1, 0.0032225743180907384, '[3127]')
# (5760, 47, 4, 0.01084940521169292, '[3131, 3169, 3326, 3544]')
# (11325, 47, 1, 0.0044346327382807395, '[3132]')
# (11064, 47, 1, 0.006006196101365212, '[3136]')
# (7431, 47, 2, 0.012012392202730425, '[3144, 3250]')
# (1324, 47, 1, 0.006006196101365212, '[3145]')
# (414, 47, 2, 0.01002930003194479, '[3146, 3262]')
# (7865, 47, 2, 0.01002930003194479, '[3147, 3263]')
# (10890, 47, 1, 0.006006196101365212, '[3155]')
# (2715, 47, 1, 0.0046954434737088635, '[3160]')
# (11290, 47, 2, 0.008428240806967111, '[3163, 3405]')
# (9842, 47, 1, 0.004214120403483556, '[3170]')
# (6576, 47, 1, 0.006006196101365212, '[3171]')
# (1433, 47, 1, 0.006006196101365212, '[3172]')
# (10023, 47, 1, 0.005426178823673557, '[3173]')
# (7439, 47, 3, 0.018018588304095636, '[3175, 3364, 3398]')
# (545, 47, 2, 0.010852357647347113, '[3178, 3296]')
# (8844, 47, 1, 0.0046954434737088635, '[3180]')
# (8522, 47, 1, 0.0034430866528879227, '[3181]')
# (4746, 47, 1, 0.006006196101365212, '[3183]')
# (9671, 47, 1, 0.003703897388316047, '[3185]')
# (144, 47, 1, 0.0038546154605890847, '[3193]')
# (7696, 47, 1, 0.004214120403483556, '[3194]')
# (6212, 47, 2, 0.005889668814655309, '[3196, 3219]')
# (2260, 47, 1, 0.0046954434737088635, '[3197]')
# (11304, 47, 1, 0.003567556307614081, '[3200]')
# (8943, 47, 1, 0.006006196101365212, '[3212]')
# (7603, 47, 1, 0.003567556307614081, '[3214]')
# (5258, 47, 1, 0.002863069375196268, '[3232]')
# (8903, 47, 1, 0.0032225743180907384, '[3239]')
# (7866, 47, 1, 0.005014650015972395, '[3243]')
# (9958, 47, 1, 0.005426178823673557, '[3269]')
# (1471, 47, 1, 0.006006196101365212, '[3273]')
# (5596, 47, 1, 0.006006196101365212, '[3288]')
# (2694, 47, 2, 0.010852357647347113, '[3290, 3396]')
# (3128, 47, 2, 0.012012392202730425, '[3291, 3317]')
# (3601, 47, 1, 0.0032225743180907384, '[3292]')
# (7613, 47, 1, 0.002642557040399083, '[3314]')
# (3878, 47, 1, 0.005014650015972395, '[3315]')
# (6889, 47, 1, 0.00332858567000313, '[3316]')
# (9363, 47, 1, 0.005426178823673557, '[3319]')
# (2881, 47, 1, 0.004023103930579578, '[3320]')
# (8733, 47, 1, 0.0034430866528879227, '[3328]')
# (7430, 47, 1, 0.006006196101365212, '[3331]')
# (9497, 47, 1, 0.006006196101365212, '[3333]')
# (308, 47, 1, 0.006006196101365212, '[3339]')
# (7293, 47, 1, 0.004023103930579578, '[3352]')
# (11559, 47, 1, 0.0044346327382807395, '[3359]')
# (5274, 47, 1, 0.0044346327382807395, '[3373]')
# (7469, 47, 1, 0.003567556307614081, '[3377]')
# (7612, 47, 1, 0.004214120403483556, '[3380]')
# (4482, 47, 1, 0.007135112615228162, '[3385]')
# (4700, 47, 1, 0.004023103930579578, '[3391]')
# (6896, 47, 3, 0.009572579042638795, '[3392, 3551, 3625]')
# (7883, 47, 1, 0.00271235130292323, '[3401]')
# (5306, 47, 1, 0.005426178823673557, '[3403]')
# (10142, 47, 1, 0.0044346327382807395, '[3406]')
# (5943, 47, 1, 0.008589208125588804, '[3413]')
# (4665, 47, 1, 0.004023103930579578, '[3415]')
# (339, 47, 1, 0.010329259958663769, '[3423]')
# (4785, 47, 1, 0.006006196101365212, '[3430]')
# (3855, 47, 1, 0.02261179833478042, '[3438]')
# (9367, 47, 1, 0.002863069375196268, '[3440]')
# (7997, 47, 1, 0.0030315578451867616, '[3441]')
# (1982, 47, 1, 0.0029448344073276546, '[3444]')
# (6729, 47, 1, 0.006006196101365212, '[3445]')
# (940, 47, 1, 0.0034430866528879227, '[3470]')
# (4024, 47, 1, 0.0034430866528879227, '[3477]')
# (4274, 47, 1, 0.0046954434737088635, '[3478]')
# (2145, 47, 1, 0.002863069375196268, '[3489]')
# (2208, 47, 1, 0.006006196101365212, '[3504]')
# (1549, 47, 1, 0.0025760102222212636, '[3541]')
# (4794, 47, 1, 0.005014650015972395, '[3547]')
# (3222, 47, 1, 0.004023103930579578, '[3548]')
# (4699, 47, 2, 0.005152020444442527, '[3550, 3624]')
# (7767, 47, 1, 0.005014650015972395, '[3552]')
# (4033, 47, 3, 0.0071794342819790965, '[3554, 3572, 3630]')
# (8240, 47, 1, 0.0034430866528879227, '[3555]')
# (2760, 47, 1, 0.003567556307614081, '[3556]')
# (10256, 47, 1, 0.005014650015972395, '[3566]')
# (5180, 47, 1, 0.004214120403483556, '[3583]')
# (6741, 47, 1, 0.0020400117597939448, '[3587]')
# (1403, 47, 1, 0.004023103930579578, '[3591]')
# (9080, 47, 1, 0.0022830520975046127, '[3617]')
# (2778, 47, 1, 0.0034430866528879227, '[3618]')
# (2967, 47, 1, 0.0034430866528879227, '[3622]')
# (8698, 47, 1, 0.0044346327382807395, '[3626]')
